# %% [markdown]
# **Accessing and Using OpenAlex**

# %% [markdown]
# This guide is written for accesing OpenAlex, a large dataset of research works, researchers, venues and institutions.
# As of Aug 1st 2022, there are two ways to access OpenAlex:
# - download the entire dataset
# - using the official API
#
# In this tutorial, we will walk through both approaches.

# %% [markdown]
# To download a snapshot of the OpenAlex dataset, you can follow the official tutoral here: https://docs.openalex.org/download-snapshot
# The dataset is stored in Amazon S3, in the form of gzip-compressed JSON lines. By following the tutoral, you can format the JSON files downloaded from S3 and upload the dataset to either a data warehouse (e.g. BigQuery) or a relational database (e.g. PostgreSQL). For this summer school, we created a sample of the dataset under the directory "./datasets/s4/openalex_sample/".

# %%
# Loading Python Packages
import numpy as np
import pandas as pd

# %%
# Showing all the files under the directory. It shows that all the tables are in parquet. 
# we can load those tables with Pandas and PyArrow
# !ls ./datasets/s4/openalex_sample/
# Out:
# authors_counts_by_year.parquet
# authors_ids.parquet
# authors.parquet
# concepts_ancestors.parquet
# concepts_counts_by_year.parquet
# concepts_ids.parquet
# concepts.parquet
# concepts_related_concepts.parquet
# institutions_associated_institutions.parquet
# institutions_counts_by_year.parquet
# institutions_geo.parquet
# institutions_ids.parquet
# institutions.parquet
# venues_counts_by_year.parquet
# venues_ids.parquet
# venues.parquet
# works_alternate_host_venues.parquet
# works_authorships.parquet
# works_biblio.parquet
# works_concepts.parquet
# works_ids.parquet
# works_mesh.parquet
# works_open_access.parquet
# works.parquet
# works_referenced_works.parquet
# works_related_works.parquet

# %%
# !pip install pyarrow
# Out:
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.8/site-packages (8.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /opt/conda/lib/python3.8/site-packages (from pyarrow) (1.19.5)
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None

# %%
authors = pd.read_parquet('./datasets/s4/openalex_sample/authors.parquet')
works = pd.read_parquet('./datasets/s4/openalex_sample/works.parquet')

# %%
authors.head()
# Out:
#                                 id                                  orcid  \
# 0  https://openalex.org/A102677832                                   None
# 1  https://openalex.org/A102677832                                   None
# 2  https://openalex.org/A102677832                                   None
# 3  https://openalex.org/A104275227                                   None
# 4   https://openalex.org/A10451749  https://orcid.org/0000-0002-6418-2793
#
#                display_name display_name_alternatives works_count  \
# 0  Fausto Arellano-Carbajal                        []           4
# 1  Fausto Arellano-Carbajal                        []           4
# 2  Fausto Arellano-Carbajal                        []           4
# 3        Benedick A. Fraass                        []         280
# 4               Ron O. Dror                        []         206
#
#   cited_by_count            last_known_institution  \
# 0            207   https://openalex.org/I170203145
# 1            207   https://openalex.org/I170203145
# 2            207   https://openalex.org/I170203145
# 3           8629  https://openalex.org/I1282927834
# 4          25004    https://openalex.org/I97018004
#
#                                        works_api_url updated_date
# 0  https://api.openalex.org/works?filter=author.i...   2022-02-28
# 1  https://api.openalex.org/works?filter=author.i...   2022-02-28
# 2  https://api.openalex.org/works?filter=author.i...   2022-02-28
# 3  https://api.openalex.org/works?filter=author.i...   2022-03-09
# 4  https://api.openalex.org/works?filter=author.i...   2022-03-09

# %%
works.head()
# Out:
#                                  id  \
# 0  https://openalex.org/W2320228714
# 1  https://openalex.org/W2320401797
# 2  https://openalex.org/W2320853052
# 3  https://openalex.org/W2321209815
# 4  https://openalex.org/W2322514663
#
#                                            doi  \
# 0     https://doi.org/10.18632/oncotarget.8338
# 1  https://doi.org/10.1109/access.2016.2548980
# 2     https://doi.org/10.18632/oncotarget.7745
# 3     https://doi.org/10.18632/oncotarget.8553
# 4  https://doi.org/10.1016/j.procs.2016.02.014
#
#                                                title  \
# 0  Upregulation of long intergenic noncoding RNA ...
# 1  Ubiquitous Biofeedback Serious Game for Stress...
# 2  Suppression of miR-204 enables oral squamous c...
# 3  Engineered nanoparticles induce cell apoptosis...
# 4  Automated Discovery of JavaScript Code Injecti...
#
#                                         display_name publication_year  \
# 0  Upregulation of long intergenic noncoding RNA ...             2016
# 1  Ubiquitous Biofeedback Serious Game for Stress...             2016
# 2  Suppression of miR-204 enables oral squamous c...             2016
# 3  Engineered nanoparticles induce cell apoptosis...             2016
# 4  Automated Discovery of JavaScript Code Injecti...             2016
#
#   publication_date             type cited_by_count is_retracted is_paratext  \
# 0       2016-03-24  journal-article             52        False       False
# 1       2016-03-31  journal-article             35        False       False
# 2       2016-02-26  journal-article             51        False       False
# 3       2016-04-02  journal-article             53        False       False
# 4       2016-03-01  journal-article             15        False       False
#
#                                     cited_by_api_url abstract_inverted_index
# 0  https://api.openalex.org/works?filter=cites:W2...           "{""//"": [0]
# 1  https://api.openalex.org/works?filter=cites:W2...      "{""Serious"": [0]
# 2  https://api.openalex.org/works?filter=cites:W2...          "{""The"": [0]
# 3  https://api.openalex.org/works?filter=cites:W2...   "{""Engineered"": [0]
# 4  https://api.openalex.org/works?filter=cites:W2...         "{""This"": [0]

# %% [markdown]
# More details about data manipulation and processing using Pandas will be introduced in tomorrow's section

# %% [markdown]
# While it is more convenient to download the entire snapshot to your computer, querying the dataset requires a lot of computational power and disk space (about 300 GB). When computational resources are limited, accessing OpenAlex through the official API could be a better choice.

# %%
import requests
import json

# %% [markdown]
# The API (Application Programming Interface) is a convinient way to get OpenAlex data. To use an API, we make calls to request data from the computer hosting the OpenAlex data. In order to do that, one way is to use the "requests" package imported above.

# %% [markdown]
# To get a single entity from OpenAlex, we need to construct an URL as:
# ```
# https://api.openalex.org/<entity_name>/<entity_id>
# ```
#
# To give an example, let's retrieve a research work using the API:

# %%
works = pd.read_parquet('./datasets/s4/openalex_sample/works.parquet')

# %%
# Pick the first research work from the table "works"
work_to_retrieve = works.loc[0]

# %%
print('OpenAlex ID: ' + work_to_retrieve['id'] + '\n')
print('Title: ' + work_to_retrieve['title'] + '\n')
print('Publication Year: ' + str(work_to_retrieve['publication_year']) + '\n')
print('Cited by: ' + str(work_to_retrieve['cited_by_count']))
# Out:
# OpenAlex ID: https://openalex.org/W2320228714
#
# Title: Upregulation of long intergenic noncoding RNA 00673 promotes tumor proliferation via LSD1 interaction and repression of NCALD in non-small-cell lung cancer
#
# Publication Year: 2016
#
# Cited by: 52

# %% [markdown]
# The last bit of the OpenAlex id (W2320228714) is the "enitity_id" for the API URL

# %%
print(works.loc[0, 'id'])
# Out:
# https://openalex.org/W2320228714

# %% [markdown]
# By making an API request, we will receive a JSON response. We then parse it and save it as an Python dictionary object

# %%
work_W2320228714 = requests.get(
    'https://api.openalex.org/works/W2320228714'
).json()

# %%
work_W2320228714
# Out:
# {'id': 'https://openalex.org/W2320228714',
#  'doi': 'https://doi.org/10.18632/oncotarget.8338',
#  'title': 'Upregulation of long intergenic noncoding RNA 00673 promotes tumor proliferation via LSD1 interaction and repression of NCALD in non-small-cell lung cancer',
#  'display_name': 'Upregulation of long intergenic noncoding RNA 00673 promotes tumor proliferation via LSD1 interaction and repression of NCALD in non-small-cell lung cancer',
#  'publication_year': 2016,
#  'publication_date': '2016-03-24',
#  'ids': {'openalex': 'https://openalex.org/W2320228714',
#   'doi': 'https://doi.org/10.18632/oncotarget.8338',
#   'mag': '2320228714',
#   'pmid': 'https://pubmed.ncbi.nlm.nih.gov/27027352',
#   'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/5041926'},
#  'host_venue': {'id': 'https://openalex.org/V126644158',
#   'issn_l': '1949-2553',
#   'issn': ['1949-2553'],
#   'display_name': 'Oncotarget',
#   'publisher': 'Impact Journals, LLC',
#   'type': 'publisher',
#   'url': 'https://doi.org/10.18632/oncotarget.8338',
#   'is_oa': True,
#   'version': 'publishedVersion',
#   'license': 'cc-by'},
#  'type': 'journal-article',
#  'open_access': {'is_oa': True,
#   'oa_status': 'gold',
#   'oa_url': 'http://www.oncotarget.com/index.php?journal=oncotarget&page=article&op=download&path%5B%5D=8338&path%5B%5D=24721'},
#  'authorships': [{'author_position': 'first',
#    'author': {'id': 'https://openalex.org/A2277063275',
#     'display_name': 'Xuefei Shi',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I881766915',
#      'display_name': 'Nanjing University',
#      'ror': 'https://ror.org/01rxvg760',
#      'country_code': 'CN',
#      'type': 'education'}],
#    'raw_affiliation_string': 'Department of Respiratory Medicine, Jinling Hospital Nanjing University School of Medicine  Nanjing China'},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A2175885033',
#     'display_name': 'Chenhui Ma',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I881766915',
#      'display_name': 'Nanjing University',
#      'ror': 'https://ror.org/01rxvg760',
#      'country_code': 'CN',
#      'type': 'education'}],
#    'raw_affiliation_string': 'Department of Respiratory Medicine, Jinling Hospital Nanjing University School of Medicine  Nanjing China'},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A2119219064',
#     'display_name': 'Qingqing Zhu',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I881766915',
#      'display_name': 'Nanjing University',
#      'ror': 'https://ror.org/01rxvg760',
#      'country_code': 'CN',
#      'type': 'education'}],
#    'raw_affiliation_string': 'Department of Respiratory Medicine, Jinling Hospital Nanjing University School of Medicine  Nanjing China'},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A2166374096',
#     'display_name': 'Dongmei Yuan',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I881766915',
#      'display_name': 'Nanjing University',
#      'ror': 'https://ror.org/01rxvg760',
#      'country_code': 'CN',
#      'type': 'education'}],
#    'raw_affiliation_string': 'Department of Respiratory Medicine, Jinling Hospital Nanjing University School of Medicine  Nanjing China'},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A2255060901',
#     'display_name': 'Ming Sun',
#     'orcid': 'https://orcid.org/0000-0002-1173-2288'},
#    'institutions': [{'id': 'https://openalex.org/I83519826',
#      'display_name': 'Nanjing Medical University',
#      'ror': 'https://ror.org/059gcgy73',
#      'country_code': 'CN',
#      'type': 'education'}],
#    'raw_affiliation_string': 'Department of Biochemistry and Molecular Biology, Nanjing Medical University, Nanjing, China.'},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A2156461118',
#     'display_name': 'Xiaoling Gu',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I881766915',
#      'display_name': 'Nanjing University',
#      'ror': 'https://ror.org/01rxvg760',
#      'country_code': 'CN',
#      'type': 'education'}],
#    'raw_affiliation_string': 'Department of Respiratory Medicine, Jinling Hospital Nanjing University School of Medicine  Nanjing China'},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A2129347165',
#     'display_name': 'Guannan Wu',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I881766915',
#      'display_name': 'Nanjing University',
#      'ror': 'https://ror.org/01rxvg760',
#      'country_code': 'CN',
#      'type': 'education'}],
#    'raw_affiliation_string': 'Department of Respiratory Medicine, Jinling Hospital Nanjing University School of Medicine  Nanjing China'},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A2111824468',
#     'display_name': 'Tangfeng Lv',
#     'orcid': 'https://orcid.org/0000-0001-7224-8468'},
#    'institutions': [{'id': 'https://openalex.org/I881766915',
#      'display_name': 'Nanjing University',
#      'ror': 'https://ror.org/01rxvg760',
#      'country_code': 'CN',
#      'type': 'education'}],
#    'raw_affiliation_string': 'Department of Respiratory Medicine, Jinling Hospital Nanjing University School of Medicine  Nanjing China'},
#   {'author_position': 'last',
#    'author': {'id': 'https://openalex.org/A2137532889',
#     'display_name': 'Yong Song',
#     'orcid': 'https://orcid.org/0000-0002-5217-9431'},
#    'institutions': [{'id': 'https://openalex.org/I881766915',
#      'display_name': 'Nanjing University',
#      'ror': 'https://ror.org/01rxvg760',
#      'country_code': 'CN',
#      'type': 'education'}],
#    'raw_affiliation_string': 'Department of Respiratory Medicine, Jinling Hospital Nanjing University School of Medicine  Nanjing China'}],
#  'cited_by_count': 52,
#  'biblio': {'volume': '7',
#   'issue': '18',
#   'first_page': '25558',
#   'last_page': '25575'},
#  'is_retracted': False,
#  'is_paratext': False,
#  'concepts': [{'id': 'https://openalex.org/C62203573',
#    'wikidata': 'https://www.wikidata.org/wiki/Q15087973',
#    'display_name': 'Long non-coding RNA',
#    'level': 4,
#    'score': '0.57189316'},
#   {'id': 'https://openalex.org/C86803240',
#    'wikidata': 'https://www.wikidata.org/wiki/Q420',
#    'display_name': 'Biology',
#    'level': 0,
#    'score': '0.5163911'},
#   {'id': 'https://openalex.org/C119056186',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1431332',
#    'display_name': 'Gene silencing',
#    'level': 3,
#    'score': '0.4761536'},
#   {'id': 'https://openalex.org/C145059251',
#    'wikidata': 'https://www.wikidata.org/wiki/Q310899',
#    'display_name': 'microRNA',
#    'level': 3,
#    'score': '0.4389968'},
#   {'id': 'https://openalex.org/C60365752',
#    'wikidata': 'https://www.wikidata.org/wiki/Q5156306',
#    'display_name': 'Competing endogenous RNA',
#    'level': 5,
#    'score': '0.430214'},
#   {'id': 'https://openalex.org/C127561419',
#    'wikidata': 'https://www.wikidata.org/wiki/Q224527',
#    'display_name': 'Downregulation and upregulation',
#    'level': 3,
#    'score': '0.41736934'},
#   {'id': 'https://openalex.org/C121608353',
#    'wikidata': 'https://www.wikidata.org/wiki/Q12078',
#    'display_name': 'Cancer',
#    'level': 2,
#    'score': '0.3954228'},
#   {'id': 'https://openalex.org/C62112901',
#    'wikidata': 'https://www.wikidata.org/wiki/Q189159',
#    'display_name': 'Cell growth',
#    'level': 2,
#    'score': '0.37841535'},
#   {'id': 'https://openalex.org/C29537977',
#    'wikidata': 'https://www.wikidata.org/wiki/Q188941',
#    'display_name': 'Cell cycle',
#    'level': 3,
#    'score': '0.37509513'},
#   {'id': 'https://openalex.org/C555283112',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1637543',
#    'display_name': 'Carcinogenesis',
#    'level': 3,
#    'score': '0.37329492'},
#   {'id': 'https://openalex.org/C134320426',
#    'wikidata': 'https://www.wikidata.org/wiki/Q901026',
#    'display_name': 'Chromatin immunoprecipitation',
#    'level': 5,
#    'score': '0.3570522'},
#   {'id': 'https://openalex.org/C165864922',
#    'wikidata': 'https://www.wikidata.org/wiki/Q411391',
#    'display_name': 'Regulation of gene expression',
#    'level': 3,
#    'score': '0.34827882'},
#   {'id': 'https://openalex.org/C186310378',
#    'wikidata': 'https://www.wikidata.org/wiki/Q941796',
#    'display_name': 'Psychological repression',
#    'level': 4,
#    'score': '0.3360127'},
#   {'id': 'https://openalex.org/C150194340',
#    'wikidata': 'https://www.wikidata.org/wiki/Q26972',
#    'display_name': 'Gene expression',
#    'level': 3,
#    'score': '0.3255105'},
#   {'id': 'https://openalex.org/C86339819',
#    'wikidata': 'https://www.wikidata.org/wiki/Q407384',
#    'display_name': 'Transcription factor',
#    'level': 3,
#    'score': '0.32351452'}],
#  'mesh': [{'descriptor_ui': 'D002289',
#    'descriptor_name': 'Carcinoma, Non-Small-Cell Lung',
#    'qualifier_ui': 'Q000473',
#    'qualifier_name': 'pathology',
#    'is_major_topic': True},
#   {'descriptor_ui': 'D056466',
#    'descriptor_name': 'Histone Demethylases',
#    'qualifier_ui': 'Q000378',
#    'qualifier_name': 'metabolism',
#    'is_major_topic': True},
#   {'descriptor_ui': 'D008175',
#    'descriptor_name': 'Lung Neoplasms',
#    'qualifier_ui': 'Q000473',
#    'qualifier_name': 'pathology',
#    'is_major_topic': True},
#   {'descriptor_ui': 'D051596',
#    'descriptor_name': 'Neurocalcin',
#    'qualifier_ui': 'Q000378',
#    'qualifier_name': 'metabolism',
#    'is_major_topic': True},
#   {'descriptor_ui': 'D062085',
#    'descriptor_name': 'RNA, Long Noncoding',
#    'qualifier_ui': 'Q000235',
#    'qualifier_name': 'genetics',
#    'is_major_topic': True},
#   {'descriptor_ui': 'D000328',
#    'descriptor_name': 'Adult',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D000368',
#    'descriptor_name': 'Aged',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D000818',
#    'descriptor_name': 'Animals',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D019540',
#    'descriptor_name': 'Area Under Curve',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D014408',
#    'descriptor_name': 'Biomarkers, Tumor',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D014408',
#    'descriptor_name': 'Biomarkers, Tumor',
#    'qualifier_ui': 'Q000032',
#    'qualifier_name': 'analysis',
#    'is_major_topic': False},
#   {'descriptor_ui': 'D014408',
#    'descriptor_name': 'Biomarkers, Tumor',
#    'qualifier_ui': 'Q000235',
#    'qualifier_name': 'genetics',
#    'is_major_topic': False},
#   {'descriptor_ui': 'D002289',
#    'descriptor_name': 'Carcinoma, Non-Small-Cell Lung',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D002289',
#    'descriptor_name': 'Carcinoma, Non-Small-Cell Lung',
#    'qualifier_ui': 'Q000235',
#    'qualifier_name': 'genetics',
#    'is_major_topic': False},
#   {'descriptor_ui': 'D002289',
#    'descriptor_name': 'Carcinoma, Non-Small-Cell Lung',
#    'qualifier_ui': 'Q000378',
#    'qualifier_name': 'metabolism',
#    'is_major_topic': False},
#   {'descriptor_ui': 'D049109',
#    'descriptor_name': 'Cell Proliferation',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D049109',
#    'descriptor_name': 'Cell Proliferation',
#    'qualifier_ui': 'Q000235',
#    'qualifier_name': 'genetics',
#    'is_major_topic': False},
#   {'descriptor_ui': 'D005260',
#    'descriptor_name': 'Female',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D015972',
#    'descriptor_name': 'Gene Expression Regulation, Neoplastic',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D015972',
#    'descriptor_name': 'Gene Expression Regulation, Neoplastic',
#    'qualifier_ui': 'Q000235',
#    'qualifier_name': 'genetics',
#    'is_major_topic': False},
#   {'descriptor_ui': 'D064593',
#    'descriptor_name': 'Heterografts',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D056466',
#    'descriptor_name': 'Histone Demethylases',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D006801',
#    'descriptor_name': 'Humans',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D053208',
#    'descriptor_name': 'Kaplan-Meier Estimate',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D008175',
#    'descriptor_name': 'Lung Neoplasms',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D008175',
#    'descriptor_name': 'Lung Neoplasms',
#    'qualifier_ui': 'Q000235',
#    'qualifier_name': 'genetics',
#    'is_major_topic': False},
#   {'descriptor_ui': 'D008175',
#    'descriptor_name': 'Lung Neoplasms',
#    'qualifier_ui': 'Q000378',
#    'qualifier_name': 'metabolism',
#    'is_major_topic': False},
#   {'descriptor_ui': 'D008297',
#    'descriptor_name': 'Male',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D051379',
#    'descriptor_name': 'Mice',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D008819',
#    'descriptor_name': 'Mice, Nude',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D008875',
#    'descriptor_name': 'Middle Aged',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D051596',
#    'descriptor_name': 'Neurocalcin',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D062085',
#    'descriptor_name': 'RNA, Long Noncoding',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D012372',
#    'descriptor_name': 'ROC Curve',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D012680',
#    'descriptor_name': 'Sensitivity and Specificity',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D015854',
#    'descriptor_name': 'Up-Regulation',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False}],
#  'alternate_host_venues': [{'id': 'https://openalex.org/V126644158',
#    'display_name': 'Oncotarget',
#    'type': 'journal',
#    'url': 'http://www.oncotarget.com/index.php?journal=oncotarget&page=article&op=download&path%5B%5D=8338&path%5B%5D=24721',
#    'is_oa': True,
#    'version': 'publishedVersion',
#    'license': 'cc-by'},
#   {'id': None,
#    'display_name': 'Europe PMC',
#    'type': 'repository',
#    'url': 'http://europepmc.org/articles/PMC5041926',
#    'is_oa': True,
#    'version': 'publishedVersion',
#    'license': 'cc-by'},
#   {'id': None,
#    'display_name': 'Europe PMC',
#    'type': 'repository',
#    'url': 'http://europepmc.org/articles/pmc5041926?pdf=render',
#    'is_oa': True,
#    'version': 'publishedVersion',
#    'license': 'cc-by'},
#   {'id': None,
#    'display_name': 'PMC',
#    'type': 'repository',
#    'url': 'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC5041926',
#    'is_oa': True,
#    'version': 'publishedVersion',
#    'license': None}],
#  'referenced_works': [],
#  'related_works': ['https://openalex.org/W1990895545',
#   'https://openalex.org/W2015863218',
#   'https://openalex.org/W2087377443',
#   'https://openalex.org/W2166810745',
#   'https://openalex.org/W2215458091',
#   'https://openalex.org/W2397759082',
#   'https://openalex.org/W2401641277',
#   'https://openalex.org/W2566306318',
#   'https://openalex.org/W2582886239',
#   'https://openalex.org/W2597282914',
#   'https://openalex.org/W2735000611',
#   'https://openalex.org/W2754649611',
#   'https://openalex.org/W2755439655',
#   'https://openalex.org/W2772767466',
#   'https://openalex.org/W2917837889',
#   'https://openalex.org/W2947654194',
#   'https://openalex.org/W2996568909',
#   'https://openalex.org/W3005597885',
#   'https://openalex.org/W3136755088',
#   'https://openalex.org/W3210290986'],
#  'abstract_inverted_index': {'//': [0],
#   'Xuefei': [6],
#   'Shi': [7],
#   '1,': [8, 16],
#   '3,': [10],
#   '*': [12, 18, 96],
#   ',': [13, 19, 23, 27, 31, 35, 39, 43, 301],
#   'Chenhui': [14],
#   'Ma': [15],
#   'Qingqing': [20],
#   'Zhu': [21],
#   '1': [22, 26, 34, 38, 42, 46, 51],
#   'Dongmei': [24],
#   'Yuan': [25],
#   'Ming': [28],
#   'Sun': [29],
#   '2': [30, 68],
#   'Xiaoling': [32],
#   'Gu': [33],
#   'Guannan': [36],
#   'Wu': [37],
#   'Tangfeng': [40, 111],
#   'Lv': [41],
#   'Yong': [44, 119],
#   'Song': [45],
#   'Department': [52, 69, 84],
#   'of': [53,
#    61,
#    70,
#    85,
#    166,
#    177,
#    187,
#    199,
#    201,
#    216,
#    218,
#    228,
#    256,
#    310,
#    319,
#    323,
#    339,
#    352,
#    360],
#   'Respiratory': [54, 86],
#   'Medicine,': [55, 62, 87],
#   'Jinling': [56],
#   'Hospital,': [57, 90],
#   'Nanjing': [58, 75],
#   'University': [59],
#   'School': [60],
#   'Nanjing,': [63, 78],
#   'China': [64, 79, 92],
#   'Biochemistry': [71],
#   'and': [72, 164, 208, 231, 249, 267, 278, 281, 289, 327, 336, 383],
#   'Molecular': [73],
#   'Biology,': [74],
#   'Medical': [76],
#   'University,': [77],
#   '3': [83],
#   'Huzhou': [88],
#   'Central': [89],
#   'Huzhou,': [91],
#   'These': [97],
#   'authors': [98],
#   'have': [99, 189],
#   'contributed': [100],
#   'equally': [101],
#   'to': [102, 357],
#   'this': [103],
#   'work': [104],
#   'Correspondence': [107],
#   'to:': [108],
#   'Lv,': [112],
#   'e-mail:': [113, 121],
#   'bairoushui@163.com': [115],
#   'Song,': [120],
#   'yong_song6310@yahoo.com': [123],
#   'Keywords:': [128],
#   'linc00673,': [130, 240],
#   'proliferation,': [131, 206],
#   'LSD1,': [132],
#   'NCALD,': [133],
#   'NSCLC': [134, 342, 381],
#   'Received:': [138],
#   'December': [140],
#   '14,': [141],
#   '2015\xa0\xa0\xa0\xa0\xa0': [142],
#   'Accepted:': [143],
#   'March': [145, 150],
#   '07,': [146],
#   '2016\xa0\xa0\xa0\xa0\xa0': [147],
#   'Published:': [148],
#   '24,': [151],
#   '2016': [152],
#   'ABSTRACT': [157],
#   'Despite': [160],
#   'improvements': [161],
#   'in': [162, 222, 234, 252, 264, 269, 286, 299, 341, 380],
#   'diagnostics': [163],
#   'treatment': [165],
#   'non-small': [167],
#   'cell': [168, 276, 307],
#   'lung': [169],
#   'cancer': [170, 202, 219],
#   '(NSCLC),': [171],
#   'it': [172],
#   'remains': [173],
#   'the': [174, 317, 334, 349, 365],
#   'leading': [175],
#   'causes': [176],
#   'cancer-related': [178],
#   'mortality': [179],
#   'worldwide.': [180],
#   'In': [181],
#   'more': [182],
#   'recent': [183],
#   'years,': [184],
#   'mutiple': [185],
#   'lines': [186],
#   'evidence': [188],
#   'highlighted': [190],
#   'long': [191],
#   'noncoding': [192],
#   'RNAs': [193],
#   '(lncRNAs)': [194],
#   'serve': [195, 211],
#   'as': [196, 212],
#   'novel': [197, 214],
#   'class': [198, 215],
#   'regulators': [200, 217],
#   'biological': [203, 220],
#   'processes,': [204],
#   'including': [205, 325],
#   'apoptosis': [207],
#   'metastasis.': [209],
#   'LncRNAs': [210],
#   'a': [213, 320, 386],
#   'processes': [221],
#   'cancer,': [223],
#   'but': [224],
#   'little': [225],
#   'is': [226, 354],
#   'known': [227],
#   'their': [229],
#   'expression': [230, 242],
#   'potential': [232, 387],
#   'functions': [233],
#   'NSCLC.': [235, 253, 393],
#   'We': [236],
#   'identified': [237],
#   'an': [238],
#   'oncogene,': [239],
#   'whose': [241],
#   'level': [243],
#   'was': [244],
#   'upregulated': [245],
#   'by': [246],
#   'bioinformatics': [247],
#   'analyses': [248, 251, 346],
#   'qRT-PCR': [250],
#   'The': [254],
#   'effects': [255],
#   'linc00673': [257, 291, 303, 314, 340, 353, 375],
#   'on': [258],
#   'tumor': [259, 296, 306, 328],
#   'progression': [260, 382],
#   'were': [261],
#   'investigated': [262, 333],
#   'vitro': [265, 287],
#   'vivo': [270, 300],
#   '.': [271],
#   'Linc00673': [272],
#   'knockdown': [273, 293],
#   'significantly': [274, 294],
#   'inhibited': [275],
#   'proliferation': [277],
#   'colony-forming': [279],
#   'ability,': [280],
#   'suppressed': [282],
#   'S-phase': [283],
#   'entry': [284],
#   'shRNA': [290],
#   'mediated': [292],
#   'inhibit': [295],
#   'growth': [297],
#   'meanwhile,': [302],
#   'overexpression': [304],
#   'increased': [305],
#   'growth.': [308],
#   'Analysis': [309],
#   'RNAseq': [311],
#   'data': [312],
#   'revealed': [313],
#   'could': [315, 376],
#   'modulate': [316],
#   'transcription': [318],
#   'large': [321],
#   'amount': [322],
#   'genes': [324],
#   'oncogene': [326],
#   'suppressor': [329],
#   'gene,': [330],
#   'so': [331],
#   'we': [332],
#   'role': [335, 379],
#   'regulatory': [337],
#   'mechanism': [338],
#   'proliferation.': [343],
#   'Further': [344],
#   'mechanistic': [345],
#   'indicated': [347],
#   'that': [348, 374],
#   'oncogenic': [350],
#   'activity': [351],
#   'partially': [355],
#   'attributable': [356],
#   'its': [358],
#   'repression': [359],
#   'NCALD': [361],
#   'through': [362],
#   'association': [363],
#   'with': [364, 392],
#   'epigenetic': [366],
#   'repressor': [367],
#   'LSD1.': [368],
#   'Taken': [369],
#   'together,': [370],
#   'these': [371],
#   'findings': [372],
#   'suggested': [373],
#   'play': [377],
#   'crucial': [378],
#   'might': [384],
#   'be': [385],
#   'therapeutic': [388],
#   'target': [389],
#   'for': [390],
#   'patients': [391]},
#  'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2320228714',
#  'counts_by_year': [{'year': 2021, 'cited_by_count': 6},
#   {'year': 2020, 'cited_by_count': 12},
#   {'year': 2019, 'cited_by_count': 6},
#   {'year': 2018, 'cited_by_count': 12},
#   {'year': 2017, 'cited_by_count': 14},
#   {'year': 2016, 'cited_by_count': 2}],
#  'updated_date': '2022-05-26',
#  'created_date': '2016-06-24'}

# %%
print('OpenAlex ID: ' + work_W2320228714['id'] + '\n')
print('Title: ' + work_W2320228714['title'] + '\n')
print('Publication Year: ' + str(work_W2320228714['publication_year']) + '\n')
print('First Author： ' + [a['author']['display_name'] for a in work_W2320228714['authorships'] if (a['author_position'] == 'first')][0] + '\n')
print('Cited by: ' + str(work_W2320228714['cited_by_count']))
# Out:
# OpenAlex ID: https://openalex.org/W2320228714
#
# Title: Upregulation of long intergenic noncoding RNA 00673 promotes tumor proliferation via LSD1 interaction and repression of NCALD in non-small-cell lung cancer
#
# Publication Year: 2016
#
# First Author： Xuefei Shi
#
# Cited by: 52

# %% [markdown]
# We could do the same with other entities. For example, we can retrieve a venue, but this time, let's try getting a random venue:

# %%
random_venue = requests.get(
    'https://api.openalex.org/venues/random'
).json()

# %%
random_venue
# Out:
# {'id': 'https://openalex.org/V2764511345',
#  'issn_l': '1450-2267',
#  'issn': ['1450-2267'],
#  'display_name': 'European journal of social sciences',
#  'publisher': None,
#  'works_count': 830,
#  'cited_by_count': 2024,
#  'is_oa': None,
#  'is_in_doaj': None,
#  'homepage_url': None,
#  'ids': {'openalex': 'https://openalex.org/V2764511345',
#   'issn_l': '1450-2267',
#   'mag': '2764511345',
#   'issn': ['1450-2267']},
#  'x_concepts': [{'id': 'https://openalex.org/C17744445',
#    'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#    'display_name': 'Political science',
#    'level': 0,
#    'score': 68.9},
#   {'id': 'https://openalex.org/C199539241',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#    'display_name': 'Law',
#    'level': 1,
#    'score': 63.9},
#   {'id': 'https://openalex.org/C162324750',
#    'wikidata': 'https://www.wikidata.org/wiki/Q8134',
#    'display_name': 'Economics',
#    'level': 0,
#    'score': 59.4},
#   {'id': 'https://openalex.org/C144024400',
#    'wikidata': 'https://www.wikidata.org/wiki/Q21201',
#    'display_name': 'Sociology',
#    'level': 0,
#    'score': 54.8},
#   {'id': 'https://openalex.org/C15744967',
#    'wikidata': 'https://www.wikidata.org/wiki/Q9418',
#    'display_name': 'Psychology',
#    'level': 0,
#    'score': 52.0},
#   {'id': 'https://openalex.org/C138885662',
#    'wikidata': 'https://www.wikidata.org/wiki/Q5891',
#    'display_name': 'Philosophy',
#    'level': 0,
#    'score': 50.5},
#   {'id': 'https://openalex.org/C144133560',
#    'wikidata': 'https://www.wikidata.org/wiki/Q4830453',
#    'display_name': 'Business',
#    'level': 0,
#    'score': 48.4},
#   {'id': 'https://openalex.org/C41008148',
#    'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#    'display_name': 'Computer science',
#    'level': 0,
#    'score': 41.7},
#   {'id': 'https://openalex.org/C205649164',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#    'display_name': 'Geography',
#    'level': 0,
#    'score': 39.8},
#   {'id': 'https://openalex.org/C86803240',
#    'wikidata': 'https://www.wikidata.org/wiki/Q420',
#    'display_name': 'Biology',
#    'level': 0,
#    'score': 38.3},
#   {'id': 'https://openalex.org/C33923547',
#    'wikidata': 'https://www.wikidata.org/wiki/Q395',
#    'display_name': 'Mathematics',
#    'level': 0,
#    'score': 38.3},
#   {'id': 'https://openalex.org/C95457728',
#    'wikidata': 'https://www.wikidata.org/wiki/Q309',
#    'display_name': 'History',
#    'level': 0,
#    'score': 32.3},
#   {'id': 'https://openalex.org/C71924100',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#    'display_name': 'Medicine',
#    'level': 0,
#    'score': 30.4},
#   {'id': 'https://openalex.org/C166957645',
#    'wikidata': 'https://www.wikidata.org/wiki/Q23498',
#    'display_name': 'Archaeology',
#    'level': 1,
#    'score': 29.6},
#   {'id': 'https://openalex.org/C121332964',
#    'wikidata': 'https://www.wikidata.org/wiki/Q413',
#    'display_name': 'Physics',
#    'level': 0,
#    'score': 29.0},
#   {'id': 'https://openalex.org/C41895202',
#    'wikidata': 'https://www.wikidata.org/wiki/Q8162',
#    'display_name': 'Linguistics',
#    'level': 1,
#    'score': 26.6},
#   {'id': 'https://openalex.org/C50522688',
#    'wikidata': 'https://www.wikidata.org/wiki/Q189833',
#    'display_name': 'Economic growth',
#    'level': 1,
#    'score': 23.7},
#   {'id': 'https://openalex.org/C111472728',
#    'wikidata': 'https://www.wikidata.org/wiki/Q9471',
#    'display_name': 'Epistemology',
#    'level': 1,
#    'score': 22.7},
#   {'id': 'https://openalex.org/C127413603',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#    'display_name': 'Engineering',
#    'level': 0,
#    'score': 22.5},
#   {'id': 'https://openalex.org/C77805123',
#    'wikidata': 'https://www.wikidata.org/wiki/Q161272',
#    'display_name': 'Social psychology',
#    'level': 1,
#    'score': 22.5},
#   {'id': 'https://openalex.org/C18903297',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7150',
#    'display_name': 'Ecology',
#    'level': 1,
#    'score': 21.9},
#   {'id': 'https://openalex.org/C105795698',
#    'wikidata': 'https://www.wikidata.org/wiki/Q12483',
#    'display_name': 'Statistics',
#    'level': 1,
#    'score': 20.7}],
#  'counts_by_year': [{'year': 2022, 'works_count': 0, 'cited_by_count': 11},
#   {'year': 2021, 'works_count': 17, 'cited_by_count': 26},
#   {'year': 2020, 'works_count': 88, 'cited_by_count': 63},
#   {'year': 2019, 'works_count': 109, 'cited_by_count': 120},
#   {'year': 2018, 'works_count': 167, 'cited_by_count': 115},
#   {'year': 2017, 'works_count': 137, 'cited_by_count': 107},
#   {'year': 2016, 'works_count': 22, 'cited_by_count': 175},
#   {'year': 2015, 'works_count': 22, 'cited_by_count': 228},
#   {'year': 2014, 'works_count': 23, 'cited_by_count': 316},
#   {'year': 2013, 'works_count': 23, 'cited_by_count': 310},
#   {'year': 2012, 'works_count': 13, 'cited_by_count': 246}],
#  'works_api_url': 'https://api.openalex.org/works?filter=host_venue.id:V2764511345',
#  'updated_date': '2022-07-31T10:53:21.043225',
#  'created_date': '2017-10-27'}

# %% [markdown]
# In many cases, instead of getting only one thing at a time, we want to get of list of things, In the code cell below, we ask for all concepts, instead of specifying a concept by its ID. The API returns a meta object with details about the query, along with a long list of concepts.

# %%
requests.get(
    'https://api.openalex.org/concepts'
).json()
# Out:
# {'meta': {'count': 65073,
#   'db_response_time_ms': 28,
#   'page': 1,
#   'per_page': 25},
#  'results': [{'id': 'https://openalex.org/C41008148',
#    'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#    'display_name': 'Computer science',
#    'level': 0,
#    'description': 'theoretical study of the formal foundation enabling the automated processing or computation of information, for example on a computer or over a data transmission network',
#    'works_count': 40334190,
#    'cited_by_count': 218510853,
#    'ids': {'openalex': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'mag': '41008148',
#     'wikipedia': 'https://en.wikipedia.org/wiki/Computer%20science',
#     'umls_cui': ['C0599726']},
#    'image_url': 'https://upload.wikimedia.org/wikipedia/commons/6/6a/Sorting_quicksort_anim.gif',
#    'image_thumbnail_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Sorting_quicksort_anim.gif/100px-Sorting_quicksort_anim.gif',
#    'international': {'display_name': {'af': 'Informatika',
#      'am': 'የኮምፒውተር፡ጥናት',
#      'an': 'Informatica',
#      'ar': 'علم الحاسوب',
#      'arz': 'علم الكمبيوتر',
#      'as': 'কম্পিউটাৰ বিজ্ঞান',
#      'ast': 'Informática',
#      'az': 'İnformatika',
#      'azb': 'بیلگی\u200cسایار بیلیمی',
#      'ba': 'Информатика',
#      'bar': 'Informatik',
#      'bcl': 'Siyensyang pangkompyuter',
#      'be': 'інфарматыка',
#      'be-tarask': 'інфарматыка',
#      'bg': 'Информатика',
#      'bho': 'कंप्यूटर बिज्ञान',
#      'bn': 'কম্পিউটার বিজ্ঞান',
#      'br': 'stlenneg',
#      'bs': 'Računarstvo',
#      'ca': 'ciències de la computació',
#      'ce': 'Категори:Информатика',
#      'ckb': 'زانستی کۆمپیوتەر',
#      'co': 'informatica',
#      'cs': 'počítačová věda',
#      'csb': 'Infòrmatika',
#      'cy': 'cyfrifiadureg',
#      'da': 'datalogi',
#      'de': 'Informatik',
#      'de-ch': 'Informatik',
#      'diq': 'İnformatik',
#      'el': 'Επιστήμη υπολογιστών',
#      'eml': 'Informàtica',
#      'en': 'computer science',
#      'en-ca': 'Informatics',
#      'en-gb': 'computer science',
#      'eo': 'komputiko',
#      'es': 'ciencias de la computación',
#      'et': 'Informaatika',
#      'eu': 'Informatika',
#      'ext': 'Enhormática',
#      'fa': 'انفورماتیک (رشته دانشگاهی)',
#      'fi': 'tietojenkäsittelytiede',
#      'fo': 'Teldufrøði',
#      'fr': 'informatique',
#      'frr': 'informaatik',
#      'fur': 'Informatiche',
#      'fy': 'ynformatika',
#      'ga': 'ríomheolaíocht',
#      'gcr': 'Lenfòrmatik',
#      'gd': 'saidheans choimpiutairean',
#      'gl': 'ciencias da computación',
#      'gsw': 'Informatik',
#      'gu': 'કમ્પ્યુટર વિજ્ઞાન',
#      'gv': 'Sheanse co-earrooagh',
#      'hak': 'Thien-nó Khô-ho̍k',
#      'he': 'מדעי המחשב',
#      'hi': 'संगणक विज्ञान',
#      'hr': 'Informatika',
#      'hsb': 'informatika',
#      'ht': 'Enfòmatik',
#      'hu': 'számítástudomány',
#      'hy': 'ինֆորմատիկա',
#      'ia': 'Informatica',
#      'id': 'ilmu komputer',
#      'ie': 'Informatica',
#      'io': 'Informatiko',
#      'is': 'Tölvunarfræði',
#      'it': 'informatica',
#      'iu': 'ᑐᓴᐅᒪᖃᑦᑕᐅᑎᔾᔪᑎᓂᒃ ᐊᐅᓚᑦᑎᔩᑦ/tusaumaqattautijjutinik aulattijiit',
#      'ja': '計算機科学',
#      'jbo': 'samske',
#      'ka': 'ინფორმატიკა',
#      'kaa': 'Informatika',
#      'kab': 'Tasenselkimt',
#      'kk': 'Информатика',
#      'kl': 'Qarasaasialerinermik ilisimatusarneq',
#      'km': 'វិទ្យាសាស្ត្រ\u200bកុំព្យូទ័រ',
#      'kn': 'ಗಣಕ ವಿಜ್ಞಾನ',
#      'ko': '컴퓨터 과학',
#      'ku': 'Informatîk',
#      'la': 'informatica',
#      'lad': 'Informatika',
#      'lb': 'Informatik',
#      'li': 'Informatica',
#      'lij': 'Informatica',
#      'lmo': 'Informadega',
#      'lt': 'Informatika',
#      'ltg': 'Datorzineiba',
#      'lv': 'datorzinātne',
#      'mdf': 'Информатикась',
#      'mg': 'Informatika',
#      'mhr': 'Информатике',
#      'min': 'Ilmu komputer',
#      'mk': 'информатика',
#      'ml': 'കമ്പ്യൂട്ടർ ശാസ്ത്രം',
#      'mn': 'Компьютерийн шинжлэх ухаан',
#      'mr': 'संगणक विज्ञान',
#      'ms': 'sains komputer',
#      'ms-arab': 'ساءين\u200cس کومڤوتر',
#      'mwl': 'Ciéncia de la cumputaçon',
#      'my': 'ကွန်ပျူတာသိပ္ပံ',
#      'nan': 'Tiān-náu kho-ha̍k',
#      'nap': 'Nfurmateca',
#      'nb': 'datateknikk',
#      'nds-nl': 'Informatika',
#      'ne': 'कम्प्युटर विज्ञान',
#      'new': 'कम्प्युटर विज्ञान',
#      'nl': 'informatica',
#      'nn': 'datateknikk',
#      'nov': 'informatike',
#      'nqo': 'ߕߟߋ߬ߓߊ߰ ߞߊߙߊ߲ ߥߟߊ߫ ߕߟߋ߬ߓߊ߰ ߟߐ߲',
#      'nrm': 'Informatique',
#      'oc': 'informatica',
#      'om': 'Infoormaatiksii',
#      'or': 'କମ୍ପ୍ୟୁଟର ବିଜ୍ଞାନ',
#      'os': 'информатикæ',
#      'pcd': 'Informatike',
#      'pi': 'सुशांख्य यन्त्र (कम्प्युटर) विज्ञान',
#      'pl': 'informatyka',
#      'pms': 'Anformàtica',
#      'ps': 'سولګرپوهنه',
#      'pt': 'ciência de computadores',
#      'pt-br': 'ciência da computação',
#      'ro': 'informatică',
#      'ru': 'информатика',
#      'rue': 'Інформатіка',
#      'rup': 'informaticã',
#      'sa': 'सङ्गणक शास्त्रम्',
#      'sah': 'Информатика',
#      'sc': 'Informàtica',
#      'scn': 'nfurmàtica',
#      'sco': 'computer science',
#      'sd': 'ڪمپيوٽر سائنس',
#      'sgs': 'Infuormatėka',
#      'sh': 'informatika',
#      'shi': 'Tasenselkimt',
#      'shn': 'ပၢႆးသၢႆႊၶွမ်ႇပိဝ်ႇတႃႇ',
#      'si': 'පරිගණක විද්\u200dයාව',
#      'sk': 'veda o počítačoch',
#      'sl': 'informatika',
#      'sq': 'shkencë kompjuterike',
#      'sr': 'информатика',
#      'sr-ec': 'информатика',
#      'sr-el': 'informatika',
#      'stq': 'Informoatik',
#      'su': 'Élmu komputer',
#      'sv': 'datavetenskap',
#      'sw': 'Sayansi ya tarakilishi',
#      'ta': 'கணினியியல்',
#      'te': 'కంప్యూటరు శాస్త్రం',
#      'tet': 'Definisaun Sistema Informasaun Teknologia',
#      'tg': 'илмҳои роёна',
#      'tg-cyrl': 'информатика',
#      'th': 'วิทยาการคอมพิวเตอร์',
#      'ti': 'ኮምፒዩተር ሳይንስ',
#      'tk': 'Informatika',
#      'tl': 'Impormatika',
#      'tpi': 'Save long komputa',
#      'tr': 'bilgisayar bilimi',
#      'tt': 'компьютер белеме',
#      'tt-cyrl': 'компьютер белеме',
#      'ug': 'بیلگیسايار مۈھەندیسلیغی',
#      'uk': 'інформатика',
#      'ur': 'کمپیوٹر سائنس',
#      'uz': 'Informatika',
#      'vec': 'informàtega',
#      'vi': 'khoa học máy tính',
#      'vro': 'Informaatiga',
#      'wa': 'Infôrmatike',
#      'war': 'Siyensya han komputasyon',
#      'wo': 'Xam-xamu nosukaay',
#      'wuu': '计算机科学',
#      'xmf': 'ინფორმატიკა',
#      'yo': 'Ìfitónilétí',
#      'yue': '電腦科學',
#      'zea': 'Informaotica',
#      'zh': '計算機科學',
#      'zh-cn': '计算机科学',
#      'zh-hans': '计算机科学',
#      'zh-hant': '電腦科學',
#      'zh-hk': '電腦科學',
#      'zh-mo': '電腦科學',
#      'zh-my': '电脑科学',
#      'zh-sg': '电脑科学',
#      'zh-tw': '電腦科學'},
#     'description': {'ar': 'دراسة العمليات التي تتفاعل مع بيانات و التي يمكن تمثيلها كبيانات في شكل برامج',
#      'az': 'elm sahəsi',
#      'bn': 'কম্পিউটার নামক যন্ত্রের সাহায্যে তথ্য প্রক্রিয়াজাতকরণ ও গণনার ভিত্তির প্রণালীবদ',
#      'bs': 'naučna disciplina koja se bavi svim aspektima razvoja računara',
#      'ca': 'estudi teòric de la base formal que permet el processament o el càlcul automatitzat de la informació',
#      'cs': 'věda studující principy strojového zpracování informací',
#      'da': 'disciplin med rødder i matematisk logik, lingvistik og elektroteknik',
#      'de': 'Wissenschaft von der systematischen Verarbeitung von Informationen',
#      'en': 'theoretical study of the formal foundation enabling the automated processing or computation of information, for example on a computer or over a data transmission network',
#      'en-gb': 'study of the theoretical foundations of information and computation',
#      'eo': 'scienco pri teoria fondado de informo kaj komputado',
#      'es': 'ciencia dedicada a la computación y al procesado de información',
#      'fa': 'علم اطلاعات و پردازش اطلاعات و مهندسی سامانه\u200cهای اطلاعاتی',
#      'fi': 'tieteenala, joka tutkii tietotekniikkaan ja sen käyttöön liittyviä ongelmia',
#      'fr': "domaine d'étude scientifique",
#      'gl': 'ciencia dedicada á computación e ao procesado de información',
#      'he': 'תחום מחקר של תיאוריות בסיסיות הקשורות במידע ובמחשוב.',
#      'hsb': 'wědomosć wo systematiskim předźěłanju informacijow',
#      'id': 'kajian dasar teoretis dari informasi dan komputasi',
#      'it': "scienza che studia i fondamenti teorici dell'informazione e della sua computazione",
#      'ja': '情報と計算の理論的基礎、及びそのコンピュータ上への実装と応用に関する研究分野',
#      'kn': 'ಮಾಹಿತಿ ಮತ್ತು ಗಣನೆಯ ಸೈದ್ಧಾಂತಿಕ ಅಡಿಪಾಯಗಳ ಅಧ್ಯಯನ',
#      'ko': '전산 이론, 소프트웨어, 하드웨어의 중점을 둔\xa0정보과학의 한 분야',
#      'nb': 'fagfelt med røtter i matematisk logikk, lingvistikk og elektroingeniørfag',
#      'nl': 'de studie van informatie en berekening en hun toepassingen in computersystemen',
#      'pl': 'nauka zajmująca się przetwarzaniem informacji',
#      'pt': 'estudo dos fundamentos teóricos da informação e da computação',
#      'pt-br': 'estudo dos fundamentos teóricos da informação e da computação',
#      'ro': 'știință care se ocupă cu prelucrarea sistematică a datelor',
#      'ru': 'дисциплина об информации',
#      'scn': "scienza chi studìa l'elabburazzioni dî nfurmazzioni pi menzu dî calculatura elittrònici",
#      'sco': 'scienteefic an practical approach tae computation an its applications',
#      'sl': 'veda o računalniški obdelavi podatkov',
#      'sq': 'studimi i teknologjise se informacionit dhe kompjutersie',
#      'tr': 'Belirli evren kurallarına dayalı, sistematik çalışan ve elementlerin ya da ağların birbirleriyle olan ilişkisi',
#      'uk': 'наукова дисципліна',
#      'vec': "Siensa che ła stùdia i fondaminti teòreghi de l'informasion e de ła so conputasion.",
#      'vi': 'ngành học nghiên cứu về cơ sở lý thuyết và ứng dụng tự động xử lý hoặc tính toán thông tin',
#      'wa': 'syince ki studeye les copiutreces',
#      'zh': '研究信息和計算的理論基礎'}},
#    'ancestors': [],
#    'related_concepts': [{'id': 'https://openalex.org/C33923547',
#      'wikidata': None,
#      'display_name': 'Mathematics',
#      'level': 0,
#      'score': 253.91972},
#     {'id': 'https://openalex.org/C119599485',
#      'wikidata': None,
#      'display_name': 'Electrical engineering',
#      'level': 1,
#      'score': 153.01909},
#     {'id': 'https://openalex.org/C121332964',
#      'wikidata': None,
#      'display_name': 'Physics',
#      'level': 0,
#      'score': 143.93542},
#     {'id': 'https://openalex.org/C127413603',
#      'wikidata': None,
#      'display_name': 'Engineering',
#      'level': 0,
#      'score': 134.1664},
#     {'id': 'https://openalex.org/C78519656',
#      'wikidata': None,
#      'display_name': 'Mechanical engineering',
#      'level': 1,
#      'score': 109.06372},
#     {'id': 'https://openalex.org/C154945302',
#      'wikidata': None,
#      'display_name': 'Artificial intelligence',
#      'level': 1,
#      'score': 78.66415},
#     {'id': 'https://openalex.org/C11413529',
#      'wikidata': None,
#      'display_name': 'Algorithm',
#      'level': 1,
#      'score': 77.642456},
#     {'id': 'https://openalex.org/C86803240',
#      'wikidata': None,
#      'display_name': 'Biology',
#      'level': 0,
#      'score': 72.15612},
#     {'id': 'https://openalex.org/C147176958',
#      'wikidata': None,
#      'display_name': 'Civil engineering',
#      'level': 1,
#      'score': 69.927315},
#     {'id': 'https://openalex.org/C185592680',
#      'wikidata': None,
#      'display_name': 'Chemistry',
#      'level': 0,
#      'score': 69.06744},
#     {'id': 'https://openalex.org/C162324750',
#      'wikidata': None,
#      'display_name': 'Economics',
#      'level': 0,
#      'score': 68.4899},
#     {'id': 'https://openalex.org/C15744967',
#      'wikidata': None,
#      'display_name': 'Psychology',
#      'level': 0,
#      'score': 67.836555},
#     {'id': 'https://openalex.org/C199360897',
#      'wikidata': None,
#      'display_name': 'Programming language',
#      'level': 1,
#      'score': 64.66104},
#     {'id': 'https://openalex.org/C24326235',
#      'wikidata': None,
#      'display_name': 'Electronic engineering',
#      'level': 1,
#      'score': 60.35985},
#     {'id': 'https://openalex.org/C113775141',
#      'wikidata': None,
#      'display_name': 'Computer engineering',
#      'level': 1,
#      'score': 56.27748},
#     {'id': 'https://openalex.org/C115903868',
#      'wikidata': None,
#      'display_name': 'Software engineering',
#      'level': 1,
#      'score': 53.30523},
#     {'id': 'https://openalex.org/C36289849',
#      'wikidata': None,
#      'display_name': 'Social science',
#      'level': 1,
#      'score': 49.330643},
#     {'id': 'https://openalex.org/C138885662',
#      'wikidata': None,
#      'display_name': 'Philosophy',
#      'level': 0,
#      'score': 49.09181},
#     {'id': 'https://openalex.org/C105795698',
#      'wikidata': None,
#      'display_name': 'Statistics',
#      'level': 1,
#      'score': 47.862644},
#     {'id': 'https://openalex.org/C28826006',
#      'wikidata': None,
#      'display_name': 'Applied mathematics',
#      'level': 1,
#      'score': 39.67622},
#     {'id': 'https://openalex.org/C80444323',
#      'wikidata': None,
#      'display_name': 'Theoretical computer science',
#      'level': 1,
#      'score': 36.255596},
#     {'id': 'https://openalex.org/C17744445',
#      'wikidata': None,
#      'display_name': 'Political science',
#      'level': 0,
#      'score': 35.794933},
#     {'id': 'https://openalex.org/C77088390',
#      'wikidata': None,
#      'display_name': 'Database',
#      'level': 1,
#      'score': 34.62841},
#     {'id': 'https://openalex.org/C119857082',
#      'wikidata': None,
#      'display_name': 'Machine learning',
#      'level': 1,
#      'score': 34.341488},
#     {'id': 'https://openalex.org/C187736073',
#      'wikidata': None,
#      'display_name': 'Management',
#      'level': 1,
#      'score': 34.01941},
#     {'id': 'https://openalex.org/C188147891',
#      'wikidata': None,
#      'display_name': 'Cognitive science',
#      'level': 1,
#      'score': 33.328857},
#     {'id': 'https://openalex.org/C15708023',
#      'wikidata': None,
#      'display_name': 'Humanities',
#      'level': 1,
#      'score': 32.60441},
#     {'id': 'https://openalex.org/C42360764',
#      'wikidata': None,
#      'display_name': 'Chemical engineering',
#      'level': 1,
#      'score': 31.971958},
#     {'id': 'https://openalex.org/C13736549',
#      'wikidata': None,
#      'display_name': 'Industrial engineering',
#      'level': 1,
#      'score': 29.506624},
#     {'id': 'https://openalex.org/C150903083',
#      'wikidata': None,
#      'display_name': 'Biotechnology',
#      'level': 1,
#      'score': 25.505184},
#     {'id': 'https://openalex.org/C31258907',
#      'wikidata': None,
#      'display_name': 'Computer network',
#      'level': 1,
#      'score': 25.461674},
#     {'id': 'https://openalex.org/C120314980',
#      'wikidata': None,
#      'display_name': 'Distributed computing',
#      'level': 1,
#      'score': 25.227364},
#     {'id': 'https://openalex.org/C121955636',
#      'wikidata': None,
#      'display_name': 'Accounting',
#      'level': 1,
#      'score': 24.644474},
#     {'id': 'https://openalex.org/C60644358',
#      'wikidata': None,
#      'display_name': 'Bioinformatics',
#      'level': 1,
#      'score': 22.637817},
#     {'id': 'https://openalex.org/C178550888',
#      'wikidata': None,
#      'display_name': 'Business administration',
#      'level': 1,
#      'score': 22.113203},
#     {'id': 'https://openalex.org/C173608175',
#      'wikidata': None,
#      'display_name': 'Parallel computing',
#      'level': 1,
#      'score': 21.477465},
#     {'id': 'https://openalex.org/C107457646',
#      'wikidata': None,
#      'display_name': 'Human–computer interaction',
#      'level': 1,
#      'score': 21.443598},
#     {'id': 'https://openalex.org/C121684516',
#      'wikidata': None,
#      'display_name': 'Computer graphics (images)',
#      'level': 1,
#      'score': 20.948341},
#     {'id': 'https://openalex.org/C192562407',
#      'wikidata': None,
#      'display_name': 'Materials science',
#      'level': 0,
#      'score': 18.808165},
#     {'id': 'https://openalex.org/C39432304',
#      'wikidata': None,
#      'display_name': 'Environmental science',
#      'level': 0,
#      'score': 17.922344},
#     {'id': 'https://openalex.org/C42475967',
#      'wikidata': None,
#      'display_name': 'Operations research',
#      'level': 1,
#      'score': 17.310873},
#     {'id': 'https://openalex.org/C46312422',
#      'wikidata': None,
#      'display_name': 'Communication',
#      'level': 1,
#      'score': 17.22878},
#     {'id': 'https://openalex.org/C10138342',
#      'wikidata': None,
#      'display_name': 'Finance',
#      'level': 1,
#      'score': 17.1781},
#     {'id': 'https://openalex.org/C201995342',
#      'wikidata': None,
#      'display_name': 'Systems engineering',
#      'level': 1,
#      'score': 17.028011},
#     {'id': 'https://openalex.org/C38652104',
#      'wikidata': None,
#      'display_name': 'Computer security',
#      'level': 1,
#      'score': 16.644386},
#     {'id': 'https://openalex.org/C31972630',
#      'wikidata': None,
#      'display_name': 'Computer vision',
#      'level': 1,
#      'score': 16.449514},
#     {'id': 'https://openalex.org/C136229726',
#      'wikidata': None,
#      'display_name': 'Biomedical engineering',
#      'level': 1,
#      'score': 16.431839},
#     {'id': 'https://openalex.org/C159110408',
#      'wikidata': None,
#      'display_name': 'Nursing',
#      'level': 1,
#      'score': 16.200832},
#     {'id': 'https://openalex.org/C114614502',
#      'wikidata': None,
#      'display_name': 'Combinatorics',
#      'level': 1,
#      'score': 16.005728},
#     {'id': 'https://openalex.org/C118524514',
#      'wikidata': None,
#      'display_name': 'Computer architecture',
#      'level': 1,
#      'score': 14.819335},
#     {'id': 'https://openalex.org/C70721500',
#      'wikidata': None,
#      'display_name': 'Computational biology',
#      'level': 1,
#      'score': 14.150728},
#     {'id': 'https://openalex.org/C204321447',
#      'wikidata': None,
#      'display_name': 'Natural language processing',
#      'level': 1,
#      'score': 14.116703},
#     {'id': 'https://openalex.org/C54750564',
#      'wikidata': None,
#      'display_name': 'Commerce',
#      'level': 1,
#      'score': 13.512761},
#     {'id': 'https://openalex.org/C124101348',
#      'wikidata': None,
#      'display_name': 'Data mining',
#      'level': 1,
#      'score': 13.2522955},
#     {'id': 'https://openalex.org/C146978453',
#      'wikidata': None,
#      'display_name': 'Aerospace engineering',
#      'level': 1,
#      'score': 12.769067},
#     {'id': 'https://openalex.org/C118615104',
#      'wikidata': None,
#      'display_name': 'Discrete mathematics',
#      'level': 1,
#      'score': 12.72195},
#     {'id': 'https://openalex.org/C459310',
#      'wikidata': None,
#      'display_name': 'Computational science',
#      'level': 1,
#      'score': 12.502087},
#     {'id': 'https://openalex.org/C87717796',
#      'wikidata': None,
#      'display_name': 'Environmental engineering',
#      'level': 1,
#      'score': 12.180937},
#     {'id': 'https://openalex.org/C9390403',
#      'wikidata': None,
#      'display_name': 'Computer hardware',
#      'level': 1,
#      'score': 11.999481},
#     {'id': 'https://openalex.org/C79403827',
#      'wikidata': None,
#      'display_name': 'Real-time computing',
#      'level': 1,
#      'score': 11.178692},
#     {'id': 'https://openalex.org/C44154836',
#      'wikidata': None,
#      'display_name': 'Simulation',
#      'level': 1,
#      'score': 10.924057},
#     {'id': 'https://openalex.org/C1965285',
#      'wikidata': None,
#      'display_name': 'Earth science',
#      'level': 1,
#      'score': 10.543096},
#     {'id': 'https://openalex.org/C3116431',
#      'wikidata': None,
#      'display_name': 'Public administration',
#      'level': 1,
#      'score': 10.168686},
#     {'id': 'https://openalex.org/C19417346',
#      'wikidata': None,
#      'display_name': 'Pedagogy',
#      'level': 1,
#      'score': 9.322876},
#     {'id': 'https://openalex.org/C539667460',
#      'wikidata': None,
#      'display_name': 'Management science',
#      'level': 1,
#      'score': 8.963628},
#     {'id': 'https://openalex.org/C126255220',
#      'wikidata': None,
#      'display_name': 'Mathematical optimization',
#      'level': 1,
#      'score': 8.853711},
#     {'id': 'https://openalex.org/C12554922',
#      'wikidata': None,
#      'display_name': 'Biophysics',
#      'level': 1,
#      'score': 8.452211},
#     {'id': 'https://openalex.org/C180747234',
#      'wikidata': None,
#      'display_name': 'Cognitive psychology',
#      'level': 1,
#      'score': 8.136938},
#     {'id': 'https://openalex.org/C23123220',
#      'wikidata': None,
#      'display_name': 'Information retrieval',
#      'level': 1,
#      'score': 8.01752},
#     {'id': 'https://openalex.org/C49774154',
#      'wikidata': None,
#      'display_name': 'Multimedia',
#      'level': 1,
#      'score': 7.925641},
#     {'id': 'https://openalex.org/C61696701',
#      'wikidata': None,
#      'display_name': 'Engineering physics',
#      'level': 1,
#      'score': 7.748606},
#     {'id': 'https://openalex.org/C171146098',
#      'wikidata': None,
#      'display_name': 'Automotive engineering',
#      'level': 1,
#      'score': 7.697784},
#     {'id': 'https://openalex.org/C28490314',
#      'wikidata': None,
#      'display_name': 'Speech recognition',
#      'level': 1,
#      'score': 6.639613},
#     {'id': 'https://openalex.org/C133731056',
#      'wikidata': None,
#      'display_name': 'Control engineering',
#      'level': 1,
#      'score': 5.581166},
#     {'id': 'https://openalex.org/C56739046',
#      'wikidata': None,
#      'display_name': 'Knowledge management',
#      'level': 1,
#      'score': 5.2085514},
#     {'id': 'https://openalex.org/C110354214',
#      'wikidata': None,
#      'display_name': 'Engineering management',
#      'level': 1,
#      'score': 4.6380467},
#     {'id': 'https://openalex.org/C16674752',
#      'wikidata': None,
#      'display_name': 'Mining engineering',
#      'level': 1,
#      'score': 4.6359653},
#     {'id': 'https://openalex.org/C117671659',
#      'wikidata': None,
#      'display_name': 'Manufacturing engineering',
#      'level': 1,
#      'score': 4.466325},
#     {'id': 'https://openalex.org/C2522767166',
#      'wikidata': None,
#      'display_name': 'Data science',
#      'level': 1,
#      'score': 4.4244723},
#     {'id': 'https://openalex.org/C66938386',
#      'wikidata': None,
#      'display_name': 'Structural engineering',
#      'level': 1,
#      'score': 4.245082},
#     {'id': 'https://openalex.org/C161191863',
#      'wikidata': None,
#      'display_name': 'Library science',
#      'level': 1,
#      'score': 4.2409},
#     {'id': 'https://openalex.org/C30475298',
#      'wikidata': None,
#      'display_name': 'Computational physics',
#      'level': 1,
#      'score': 3.8142443},
#     {'id': 'https://openalex.org/C37621935',
#      'wikidata': None,
#      'display_name': 'Agricultural science',
#      'level': 1,
#      'score': 3.799917},
#     {'id': 'https://openalex.org/C78762247',
#      'wikidata': None,
#      'display_name': 'Petroleum engineering',
#      'level': 1,
#      'score': 3.2641659},
#     {'id': 'https://openalex.org/C170154142',
#      'wikidata': None,
#      'display_name': 'Architectural engineering',
#      'level': 1,
#      'score': 3.2228045},
#     {'id': 'https://openalex.org/C162118730',
#      'wikidata': None,
#      'display_name': 'Actuarial science',
#      'level': 1,
#      'score': 3.207602},
#     {'id': 'https://openalex.org/C145420912',
#      'wikidata': None,
#      'display_name': 'Mathematics education',
#      'level': 1,
#      'score': 3.0157754},
#     {'id': 'https://openalex.org/C88463610',
#      'wikidata': None,
#      'display_name': 'Agricultural engineering',
#      'level': 1,
#      'score': 2.8315964},
#     {'id': 'https://openalex.org/C22212356',
#      'wikidata': None,
#      'display_name': 'Transport engineering',
#      'level': 1,
#      'score': 1.9614018},
#     {'id': 'https://openalex.org/C107053488',
#      'wikidata': None,
#      'display_name': 'Construction engineering',
#      'level': 1,
#      'score': 1.6813383},
#     {'id': 'https://openalex.org/C21880701',
#      'wikidata': None,
#      'display_name': 'Process engineering',
#      'level': 1,
#      'score': 1.5742452},
#     {'id': 'https://openalex.org/C199104240',
#      'wikidata': None,
#      'display_name': 'Marine engineering',
#      'level': 1,
#      'score': 1.5703129},
#     {'id': 'https://openalex.org/C183696295',
#      'wikidata': None,
#      'display_name': 'Biochemical engineering',
#      'level': 1,
#      'score': 1.4300684}],
#    'counts_by_year': [{'year': 2022,
#      'works_count': 836727,
#      'cited_by_count': 7679769},
#     {'year': 2021, 'works_count': 1966234, 'cited_by_count': 15416250},
#     {'year': 2020, 'works_count': 2257996, 'cited_by_count': 14854162},
#     {'year': 2019, 'works_count': 2036153, 'cited_by_count': 15480431},
#     {'year': 2018, 'works_count': 1959764, 'cited_by_count': 13350438},
#     {'year': 2017, 'works_count': 1970569, 'cited_by_count': 12873325},
#     {'year': 2016, 'works_count': 1942522, 'cited_by_count': 12436905},
#     {'year': 2015, 'works_count': 1959461, 'cited_by_count': 12619560},
#     {'year': 2014, 'works_count': 1932482, 'cited_by_count': 12388770},
#     {'year': 2013, 'works_count': 1828167, 'cited_by_count': 11315097},
#     {'year': 2012, 'works_count': 1693272, 'cited_by_count': 10166249}],
#    'works_api_url': 'https://api.openalex.org/works?filter=concepts.id:C41008148',
#    'updated_date': '2022-07-31T11:37:22.681641',
#    'created_date': '2016-06-24'},
#   {'id': 'https://openalex.org/C71924100',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#    'display_name': 'Medicine',
#    'level': 0,
#    'description': 'field of study for diagnosing, treating and preventing disease',
#    'works_count': 36534002,
#    'cited_by_count': 376492274,
#    'ids': {'openalex': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'mag': '71924100',
#     'wikipedia': 'https://en.wikipedia.org/wiki/Medicine',
#     'umls_cui': ['C0013227']},
#    'image_url': 'https://upload.wikimedia.org/wikipedia/commons/d/d2/Asklepios.3.jpg',
#    'image_thumbnail_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d2/Asklepios.3.jpg/66px-Asklepios.3.jpg',
#    'international': {'display_name': {'aeb-arab': 'طب',
#      'af': 'geneeskunde',
#      'am': 'ሕክምና',
#      'an': 'medecina',
#      'ar': 'طب',
#      'arc': 'ܐܣܝܘܬܐ',
#      'arz': 'طب',
#      'as': 'চিকিৎসা বিজ্ঞান',
#      'ast': 'medicina',
#      'ay': 'Qulla',
#      'az': 'tibb',
#      'ba': 'Медицина',
#      'bcl': 'Pagbulong',
#      'be': 'медыцына',
#      'be-tarask': 'мэдыцына',
#      'bg': 'медицина',
#      'bho': 'डाक्टरी (बिद्या)',
#      'bi': 'Medisin',
#      'bm': 'Dɔkɔtɔrɔya',
#      'bn': 'চিকিৎসা বিজ্ঞান',
#      'bo': 'སྨན།',
#      'bpy': 'চিকিৎসা বিজ্ঞান',
#      'br': 'Mezegiezh',
#      'bs': 'Medicina',
#      'bxr': 'Анагааха ухаан',
#      'ca': 'medicina',
#      'cdo': 'Ĭ-hŏk',
#      'ce': 'Медицина',
#      'ceb': 'Medisina',
#      'chr': 'ᏅᏬᏘ',
#      'ckb': 'پزیشکی',
#      'co': 'Medicina',
#      'crh': 'tibbiyet',
#      'cs': 'lékařství',
#      'csb': 'Medicëna',
#      'cv': 'Медицина',
#      'cy': 'Meddygaeth',
#      'da': 'lægevidenskab',
#      'de': 'Medizin',
#      'de-ch': 'Medizin',
#      'diq': 'Tıb',
#      'el': 'ιατρική',
#      'en': 'medicine',
#      'en-ca': 'Medicine',
#      'en-gb': 'medicine',
#      'eo': 'medicino',
#      'es': 'medicina',
#      'et': 'meditsiin',
#      'eu': 'medikuntza',
#      'ext': 'medecina',
#      'fa': 'پزشکی',
#      'fi': 'lääketiede',
#      'fo': 'Læknafrøði',
#      'fr': 'médecine',
#      'frc': 'médecine',
#      'frp': 'Mèdecina',
#      'fur': 'Midisine',
#      'fy': 'genêskunde',
#      'ga': 'míochaine',
#      'gcr': 'Médsin',
#      'gd': 'Eòlas-leighis',
#      'gl': 'medicina',
#      'gsw': 'Medizin',
#      'gv': 'Lheeys',
#      'hak': 'Yî-ho̍k',
#      'he': 'רפואה',
#      'hi': 'आयुर्विज्ञान',
#      'hif': 'Dawai',
#      'hr': 'medicina',
#      'hsb': 'medicina',
#      'ht': 'Medsin',
#      'hu': 'orvostudomány',
#      'hy': 'բժշկություն',
#      'hyw': 'Բժշկութիւն',
#      'ia': 'medicina',
#      'id': 'kedokteran',
#      'ie': 'Medicina',
#      'ilo': 'medisina',
#      'inh': 'Лорал',
#      'io': 'medicino',
#      'is': 'Læknisfræði',
#      'it': 'medicina',
#      'iu': 'ᑖᒃᑎ',
#      'ja': '医学',
#      'jam': 'Medisn',
#      'jv': 'Kedhokteran',
#      'ka': 'მედიცინა',
#      'kaa': 'Meditsina',
#      'kab': 'Tasnujjya',
#      'kk': 'Медицина',
#      'kn': 'ವೈದ್ಯವಿಜ್ಞಾನ',
#      'ko': '의학',
#      'ku': 'bijîşkî',
#      'ku-latn': 'bijîşkî',
#      'kw': 'Medhegneth',
#      'ky': 'Медицина',
#      'la': 'Medicina',
#      'lad': 'Medisina',
#      'lb': 'Medezin',
#      'lfn': 'medica',
#      'li': 'Genaeskónde',
#      'lij': 'Mëxinn-a',
#      'lo': 'ແພດສາດ',
#      'lt': 'Medicina',
#      'lv': 'medicīna',
#      'min': 'Kadokteran',
#      'mk': 'медицина',
#      'ml': 'വൈദ്യം',
#      'mn': 'Анагаах ухаан',
#      'mni': 'ꯍꯤꯗꯥꯛꯂꯣꯟ',
#      'mr': 'वैद्यकशास्त्र',
#      'ms': 'perubatan',
#      'ms-arab': 'ڤراوبتن',
#      'mt': 'mediċina',
#      'mwl': 'Medecina',
#      'my': 'ဆေးပညာ',
#      'nah': 'Tīciyōtl',
#      'nan': 'I-ha̍k',
#      'nap': 'Mericina',
#      'nb': 'medisin',
#      'nds': 'Medizin',
#      'nds-nl': 'Genaeskeunde',
#      'ne': 'चिकित्साशास्त्र',
#      'new': 'वासः',
#      'nl': 'geneeskunde',
#      'nn': 'medisin',
#      'nov': 'medisine',
#      'oc': 'Medecina',
#      'or': 'ଚିକିତ୍ସା ବିଜ୍ଞାନ',
#      'os': 'медицинæ',
#      'pa': 'ਔਸ਼ਧੀ ਵਿਗਿਆਨ',
#      'pcd': 'Médecinne',
#      'pih': 'medisin',
#      'pl': 'medycyna',
#      'pnb': 'دوائی',
#      'ps': 'درملګري',
#      'pt': 'medicina',
#      'pt-br': 'medicina',
#      'qu': 'Hampi yachay',
#      'rm': 'Medischina',
#      'ro': 'medicină',
#      'ru': 'медицина',
#      'rue': 'Медіціна',
#      'sa': 'आयुर्विज्ञान',
#      'sah': 'Медицина',
#      'sat': 'ᱛᱷᱚᱠ:ᱛᱤᱠᱪᱷᱟᱹ ᱥᱟᱬᱮᱥ',
#      'sc': 'Meighina',
#      'scn': 'Midicina',
#      'sco': 'medicin',
#      'sd': 'طب',
#      'sgs': 'Medėcėna',
#      'sh': 'medicina',
#      'shi': 'amjjay',
#      'si': 'වෛද්\u200dය විද්\u200dයාව',
#      'sk': 'Medicína',
#      'sl': 'medicina',
#      'so': 'Daawo',
#      'sq': 'mjekësi',
#      'sr': 'медицина',
#      'sr-ec': 'медицина',
#      'sr-el': 'medicina',
#      'stq': 'Heelkunde',
#      'su': 'Tatamba',
#      'sv': 'medicinsk vetenskap',
#      'sw': 'Tiba',
#      'ta': 'மருத்துவம்',
#      'te': 'వైద్యశాస్త్రము',
#      'tg': 'пизишкӣ',
#      'th': 'แพทยศาสตร์',
#      'ti': 'ሕክምና',
#      'tl': 'Panggagamot',
#      'tr': 'tıp',
#      'ts': 'Vutshunguri',
#      'tt': 'Медицина',
#      'uk': 'медицина',
#      'ur': 'طب',
#      'uz': 'Tibbiyot',
#      'vec': 'medezina',
#      'vi': 'y học',
#      'vo': 'sanav',
#      'vro': 'Arstitiidüs',
#      'wa': 'Medcene',
#      'war': 'Medisina',
#      'wo': 'Paj',
#      'wuu': '醫學',
#      'xmf': 'მედიცინა',
#      'yi': 'מעדיצין',
#      'yue': '醫學',
#      'za': 'Ywhag',
#      'zh': '医学',
#      'zh-cn': '医学',
#      'zh-hant': '醫學',
#      'zh-hk': '醫學'},
#     'description': {'aeb-arab': 'علم و صنعة تطليع المرض و مداويته',
#      'ar': 'مجال لدراسة التشخيص والعلاج والوقاية من المرض',
#      'ast': "campu d'estudios pa diagnosticar, tratar y prevenir les enfermedaes humanes",
#      'be': 'Навука пра лячэнне хвароб',
#      'be-tarask': 'навука па выяўленьні, пазьбяганьні і лячэньні хваробаў',
#      'bg': 'наука за диагностициране, лечение и предотвратяване на болести и наранявания',
#      'ca': "camp d'estudi per diagnosticar, tractar i prevenir la malaltia",
#      'cs': 'věda, zabývající se diagnostikou, léčením a prevencí vzniku nemocí',
#      'da': 'videnskaben og praksis afsat til at forebygge, diagnosticere og behandle sygdomme, og for at bevare menneskers sundhed og for at undgå døden',
#      'de': 'Lehre der Vorbeugung, Erkennung und Behandlung von Krankheiten',
#      'el': 'επιστήμη και τέχνη που ασχολείται με την έρευνα και την εφαρμογή μεθόδων και τεχνικών για την πρόληψη, τη διάγνωση και τη θεραπεία των ασθενειών του ανθρώπου',
#      'en': 'field of study for diagnosing, treating and preventing disease',
#      'eo': 'scienco kaj arto pri la sano de homoj kaj bestoj',
#      'es': 'estudio de la vida, la salud, las enfermedades y la muerte del ser humano',
#      'fa': 'شاخه مطالعاتی در مورد تشخیص، درمان و پیشگیری بیماری',
#      'fi': 'tieteen ja terveydenhuollon ala, joka tutkii ja hoitaa ihmisen terveysongelmia',
#      'fr': "science et pratique étudiant l'organisation du corps humain, son fonctionnement normal et cherchant à soigner et prévenir ses pathologies",
#      'gl': 'ciencia dedicada ao estudo da vida, a saúde, as enfermidades e a morte do ser humano',
#      'he': 'תחום ידע כללי המאגד דרכים בכדי לשמר את הבריאות מפני מחלות הפוגעות בגוף',
#      'hi': 'मानव शरीर के अध्ययन व उसकी व्याधियों के निदान का विज्ञान',
#      'hr': 'znanost o sprječavanju, otkrivanju i liječenju bolesti',
#      'hsb': 'wědomosć profylaksy, spóznawanja a lěkowanja chorosćow',
#      'hu': 'tudományág',
#      'id': 'kajian atau praktik diagnosis, pengobatan, dan pencegahan penyakit',
#      'ilo': 'arte iti panangagas',
#      'it': 'scienza che si occupa della salute delle persone',
#      'ja': '生体（人体）の構造や機能、疾病について研究し、疾病を診断・治療・予防する方法を開発する学問',
#      'ko': '질병의 진료와 치료를 목적으로 하는 학문',
#      'la': 'scientia',
#      'ms': 'sains tentang pengesanan, rawatan dan pencegahan penyakit',
#      'nl': 'wetenschap die zich bezighoudt met voorkomen, diagnosticeren en behandelen van ziekten',
#      'pl': 'nauka empiryczna o diagnozowaniu, leczeniu i zapobieganiu chorobom',
#      'pt': 'ciência que busca a prevenção e cura de enfermidades',
#      'pt-br': 'ciência ou prática do diagnóstico, tratamento e prevenção das doenças',
#      'ro': 'domeniul de studiu pentru diagnosticarea, tratarea și prevenirea bolilor',
#      'ru': 'область деятельности и знаний о лечении болезней',
#      'sk': 'veda, ktorá sa zaoberá rozpoznávaním, liečením a prevenciou chorôb',
#      'sq': 'fushë e studimit për diagnostifikimin, trajtimin dhe parandalimin e sëmundjeve',
#      'sv': 'den vetenskap och praktik som ägnar sig åt att förhindra, diagnostisera och behandla sjukdomar, samt att upprätthålla mänsklig hälsa och att undvika död',
#      'tr': 'hastalıkların teşhisi, tedavisi ve önlenmesi için çalışma alanı',
#      'uk': 'галузь діяльності, наука чи практика діагностики, лікування, запобігання хвороб, переважно людини',
#      'uz': 'aperatsiya',
#      'vec': 'Siensa che ła se ocupa de ła sałute dei esari viventi',
#      'zh': '診斷，治療和預防疾病的研究領域'}},
#    'ancestors': [],
#    'related_concepts': [{'id': 'https://openalex.org/C141071460',
#      'wikidata': None,
#      'display_name': 'Surgery',
#      'level': 1,
#      'score': 104.96226},
#     {'id': 'https://openalex.org/C159110408',
#      'wikidata': None,
#      'display_name': 'Nursing',
#      'level': 1,
#      'score': 79.02369},
#     {'id': 'https://openalex.org/C127413603',
#      'wikidata': None,
#      'display_name': 'Engineering',
#      'level': 0,
#      'score': 69.63139},
#     {'id': 'https://openalex.org/C199539241',
#      'wikidata': None,
#      'display_name': 'Law',
#      'level': 1,
#      'score': 67.21371},
#     {'id': 'https://openalex.org/C86803240',
#      'wikidata': None,
#      'display_name': 'Biology',
#      'level': 0,
#      'score': 66.43467},
#     {'id': 'https://openalex.org/C138885662',
#      'wikidata': None,
#      'display_name': 'Philosophy',
#      'level': 0,
#      'score': 61.929935},
#     {'id': 'https://openalex.org/C187212893',
#      'wikidata': None,
#      'display_name': 'Pediatrics',
#      'level': 1,
#      'score': 57.680614},
#     {'id': 'https://openalex.org/C142724271',
#      'wikidata': None,
#      'display_name': 'Pathology',
#      'level': 1,
#      'score': 55.289818},
#     {'id': 'https://openalex.org/C118552586',
#      'wikidata': None,
#      'display_name': 'Psychiatry',
#      'level': 1,
#      'score': 54.235756},
#     {'id': 'https://openalex.org/C185592680',
#      'wikidata': None,
#      'display_name': 'Chemistry',
#      'level': 0,
#      'score': 52.84301},
#     {'id': 'https://openalex.org/C15744967',
#      'wikidata': None,
#      'display_name': 'Psychology',
#      'level': 0,
#      'score': 52.07612},
#     {'id': 'https://openalex.org/C199343813',
#      'wikidata': None,
#      'display_name': 'Dentistry',
#      'level': 1,
#      'score': 51.967052},
#     {'id': 'https://openalex.org/C33923547',
#      'wikidata': None,
#      'display_name': 'Mathematics',
#      'level': 0,
#      'score': 50.313683},
#     {'id': 'https://openalex.org/C121332964',
#      'wikidata': None,
#      'display_name': 'Physics',
#      'level': 0,
#      'score': 49.542545},
#     {'id': 'https://openalex.org/C42407357',
#      'wikidata': None,
#      'display_name': 'Physiology',
#      'level': 1,
#      'score': 43.246902},
#     {'id': 'https://openalex.org/C126322002',
#      'wikidata': None,
#      'display_name': 'Internal medicine',
#      'level': 1,
#      'score': 38.005802},
#     {'id': 'https://openalex.org/C42972112',
#      'wikidata': None,
#      'display_name': 'Veterinary medicine',
#      'level': 1,
#      'score': 37.586826},
#     {'id': 'https://openalex.org/C1862650',
#      'wikidata': None,
#      'display_name': 'Physical therapy',
#      'level': 1,
#      'score': 35.260742},
#     {'id': 'https://openalex.org/C105702510',
#      'wikidata': None,
#      'display_name': 'Anatomy',
#      'level': 1,
#      'score': 34.528137},
#     {'id': 'https://openalex.org/C118487528',
#      'wikidata': None,
#      'display_name': 'Ophthalmology',
#      'level': 1,
#      'score': 34.469727},
#     {'id': 'https://openalex.org/C36289849',
#      'wikidata': None,
#      'display_name': 'Social science',
#      'level': 1,
#      'score': 32.23799},
#     {'id': 'https://openalex.org/C29456083',
#      'wikidata': None,
#      'display_name': 'Gynecology',
#      'level': 1,
#      'score': 30.138542},
#     {'id': 'https://openalex.org/C98274493',
#      'wikidata': None,
#      'display_name': 'Pharmacology',
#      'level': 1,
#      'score': 28.947195},
#     {'id': 'https://openalex.org/C131872663',
#      'wikidata': None,
#      'display_name': 'Obstetrics',
#      'level': 1,
#      'score': 28.515833},
#     {'id': 'https://openalex.org/C15708023',
#      'wikidata': None,
#      'display_name': 'Humanities',
#      'level': 1,
#      'score': 25.8888},
#     {'id': 'https://openalex.org/C150903083',
#      'wikidata': None,
#      'display_name': 'Biotechnology',
#      'level': 1,
#      'score': 25.69762},
#     {'id': 'https://openalex.org/C169760540',
#      'wikidata': None,
#      'display_name': 'Neuroscience',
#      'level': 1,
#      'score': 21.594986},
#     {'id': 'https://openalex.org/C126838900',
#      'wikidata': None,
#      'display_name': 'Radiology',
#      'level': 1,
#      'score': 19.822334},
#     {'id': 'https://openalex.org/C556039675',
#      'wikidata': None,
#      'display_name': 'Traditional medicine',
#      'level': 1,
#      'score': 19.685818},
#     {'id': 'https://openalex.org/C512399662',
#      'wikidata': None,
#      'display_name': 'Family medicine',
#      'level': 1,
#      'score': 18.738947},
#     {'id': 'https://openalex.org/C143998085',
#      'wikidata': None,
#      'display_name': 'Oncology',
#      'level': 1,
#      'score': 18.646305},
#     {'id': 'https://openalex.org/C42219234',
#      'wikidata': None,
#      'display_name': 'Anesthesia',
#      'level': 1,
#      'score': 18.243666},
#     {'id': 'https://openalex.org/C89423630',
#      'wikidata': None,
#      'display_name': 'Microbiology',
#      'level': 1,
#      'score': 17.219149},
#     {'id': 'https://openalex.org/C16005928',
#      'wikidata': None,
#      'display_name': 'Dermatology',
#      'level': 1,
#      'score': 17.12297},
#     {'id': 'https://openalex.org/C194828623',
#      'wikidata': None,
#      'display_name': 'Emergency medicine',
#      'level': 1,
#      'score': 16.548315},
#     {'id': 'https://openalex.org/C203014093',
#      'wikidata': None,
#      'display_name': 'Immunology',
#      'level': 1,
#      'score': 15.333414},
#     {'id': 'https://openalex.org/C136229726',
#      'wikidata': None,
#      'display_name': 'Biomedical engineering',
#      'level': 1,
#      'score': 13.724577},
#     {'id': 'https://openalex.org/C177713679',
#      'wikidata': None,
#      'display_name': 'Intensive care medicine',
#      'level': 1,
#      'score': 11.984015},
#     {'id': 'https://openalex.org/C509550671',
#      'wikidata': None,
#      'display_name': 'Medical education',
#      'level': 1,
#      'score': 10.960836},
#     {'id': 'https://openalex.org/C99508421',
#      'wikidata': None,
#      'display_name': 'Physical medicine and rehabilitation',
#      'level': 1,
#      'score': 10.425153},
#     {'id': 'https://openalex.org/C39432304',
#      'wikidata': None,
#      'display_name': 'Environmental science',
#      'level': 0,
#      'score': 8.721579},
#     {'id': 'https://openalex.org/C33070731',
#      'wikidata': None,
#      'display_name': 'Toxicology',
#      'level': 1,
#      'score': 7.1652966},
#     {'id': 'https://openalex.org/C19417346',
#      'wikidata': None,
#      'display_name': 'Pedagogy',
#      'level': 1,
#      'score': 7.150355},
#     {'id': 'https://openalex.org/C119767625',
#      'wikidata': None,
#      'display_name': 'Optometry',
#      'level': 1,
#      'score': 5.244981},
#     {'id': 'https://openalex.org/C74909509',
#      'wikidata': None,
#      'display_name': 'Gerontology',
#      'level': 1,
#      'score': 4.942619},
#     {'id': 'https://openalex.org/C155647269',
#      'wikidata': None,
#      'display_name': 'Medicinal chemistry',
#      'level': 1,
#      'score': 4.4052873},
#     {'id': 'https://openalex.org/C37621935',
#      'wikidata': None,
#      'display_name': 'Agricultural science',
#      'level': 1,
#      'score': 4.359523},
#     {'id': 'https://openalex.org/C548259974',
#      'wikidata': None,
#      'display_name': 'Audiology',
#      'level': 1,
#      'score': 3.0096674},
#     {'id': 'https://openalex.org/C545542383',
#      'wikidata': None,
#      'display_name': 'Medical emergency',
#      'level': 1,
#      'score': 2.987898},
#     {'id': 'https://openalex.org/C186060115',
#      'wikidata': None,
#      'display_name': 'Biological system',
#      'level': 1,
#      'score': 2.4660628},
#     {'id': 'https://openalex.org/C16685009',
#      'wikidata': None,
#      'display_name': 'Andrology',
#      'level': 1,
#      'score': 1.6032703}],
#    'counts_by_year': [{'year': 2022,
#      'works_count': 879132,
#      'cited_by_count': 13626005},
#     {'year': 2021, 'works_count': 1751294, 'cited_by_count': 29295323},
#     {'year': 2020, 'works_count': 1736257, 'cited_by_count': 24875108},
#     {'year': 2019, 'works_count': 1497392, 'cited_by_count': 20735971},
#     {'year': 2018, 'works_count': 1398639, 'cited_by_count': 18480075},
#     {'year': 2017, 'works_count': 1426517, 'cited_by_count': 20100857},
#     {'year': 2016, 'works_count': 1400007, 'cited_by_count': 19050421},
#     {'year': 2015, 'works_count': 1365296, 'cited_by_count': 19463355},
#     {'year': 2014, 'works_count': 1326076, 'cited_by_count': 18901934},
#     {'year': 2013, 'works_count': 1298327, 'cited_by_count': 17722945},
#     {'year': 2012, 'works_count': 1235287, 'cited_by_count': 16456155}],
#    'works_api_url': 'https://api.openalex.org/works?filter=concepts.id:C71924100',
#    'updated_date': '2022-07-25T12:01:03.870241',
#    'created_date': '2016-06-24'},
#   {'id': 'https://openalex.org/C185592680',
#    'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#    'display_name': 'Chemistry',
#    'level': 0,
#    'description': 'branch of physical science concerned with the composition, structure and properties of matter',
#    'works_count': 20835860,
#    'cited_by_count': 330527228,
#    'ids': {'openalex': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'mag': '185592680',
#     'wikipedia': 'https://en.wikipedia.org/wiki/Chemistry',
#     'umls_cui': ['C0079107']},
#    'image_url': 'https://upload.wikimedia.org/wikipedia/commons/4/4a/Henrika_%C5%A0antel_-_Kemi%C4%8Darka.jpg',
#    'image_thumbnail_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4a/Henrika_%C5%A0antel_-_Kemi%C4%8Darka.jpg/80px-Henrika_%C5%A0antel_-_Kemi%C4%8Darka.jpg',
#    'international': {'display_name': {'af': 'chemie',
#      'am': 'የጥንተ ንጥር ጥናት',
#      'an': 'quimica',
#      'ar': 'كيمياء',
#      'arc': 'ܟܝܡܝܐ',
#      'ary': 'شيمي',
#      'arz': 'كيميا',
#      'as': 'ৰসায়ন বিজ্ঞান',
#      'ast': 'química',
#      'av': 'химия',
#      'avk': 'razopa',
#      'az': 'kimya',
#      'azb': 'شیمی',
#      'ba': 'химия',
#      'bar': 'Chemie',
#      'bcl': 'kimika',
#      'be': 'хімія',
#      'be-tarask': 'хімія',
#      'bg': 'химия',
#      'bho': 'रसायन शास्\u200dत्र',
#      'bi': 'kemistri',
#      'bjn': 'kimia',
#      'bn': 'রসায়ন',
#      'bo': 'རྫས་འགྱུར་རིག་པ།',
#      'br': 'kimiezh',
#      'bs': 'hemija',
#      'bxr': 'хими',
#      'ca': 'química',
#      'cdo': 'huá-hŏk',
#      'ce': 'хьимийа',
#      'ceb': 'kimika',
#      'chr': 'ᎠᏑᏰᏗᏧᏓᎴᎲᏓᏅᏬᏘ',
#      'ckb': 'کیمیا',
#      'co': 'chimica',
#      'crh': 'himiya',
#      'cs': 'chemie',
#      'csb': 'chemijô',
#      'cv': 'хими',
#      'cy': 'cemeg',
#      'da': 'kemi',
#      'de': 'Chemie',
#      'de-ch': 'Chemie',
#      'din': 'piöcëkätiɔɔp',
#      'diq': 'kimya',
#      'dv': 'ކީމިއާއީ އިލްމު',
#      'el': 'χημεία',
#      'eml': 'chémmica',
#      'en': 'chemistry',
#      'en-ca': 'chemistry',
#      'en-gb': 'chemistry',
#      'eo': 'kemio',
#      'es': 'química',
#      'et': 'keemia',
#      'eu': 'kimika',
#      'ext': 'química',
#      'fa': 'شیمی',
#      'fi': 'kemia',
#      'fj': 'kemisitiri',
#      'fo': 'evnafrøði',
#      'fr': 'chimie',
#      'frp': 'ch·imie',
#      'frr': 'kemii',
#      'fur': 'chimiche',
#      'fy': 'skiekunde',
#      'ga': 'ceimic',
#      'gan': '化學',
#      'gcr': 'chimi',
#      'gd': 'ceimigeachd',
#      'gl': 'química',
#      'gn': 'kimikuaa',
#      'gsw': 'Chemii',
#      'gu': 'રસાયણ શાસ્ત્ર',
#      'gv': 'kemmig',
#      'ha': 'kimiya',
#      'hak': 'fa-ho̍k',
#      'haw': 'kemika',
#      'he': 'כימיה',
#      'hi': 'रसायन शास्त्र',
#      'hif': 'rasayan vigyan',
#      'hr': 'kemija',
#      'hsb': 'chemija',
#      'ht': 'chimi',
#      'hu': 'kémia',
#      'hy': 'քիմիա',
#      'hyw': 'տարրաբանութիւն',
#      'ia': 'chimia',
#      'id': 'kimia',
#      'ie': 'chimie',
#      'ilo': 'kímika',
#      'io': 'kemio',
#      'is': 'efnafræði',
#      'it': 'chimica',
#      'iu': 'ᐃᓚᐅᕈᑎᒃᓴᓕᕆᓂᖅ',
#      'ja': '化学',
#      'jam': 'kimischri',
#      'jbo': 'xumske',
#      'jv': 'kimia',
#      'ka': 'ქიმია',
#      'kaa': 'ximiya',
#      'kab': 'takrura',
#      'kbp': 'siimii lɛɣtʋ',
#      'ki': 'kemu',
#      'kk': 'химия',
#      'km': 'គីមីវិទ្យា',
#      'kn': 'ರಸಾಯನಶಾಸ್ತ್ರ',
#      'ko': '화학',
#      'ks': 'عٔلمہِ کیٖمِیا',
#      'ku': 'kîmya',
#      'kw': 'kymystry',
#      'ky': 'химия',
#      'la': 'chemia',
#      'lad': 'kemika',
#      'lb': 'Chimie',
#      'lez': 'химия',
#      'lfn': 'cimica',
#      'lg': 'ebyobuziba',
#      'li': 'Chemie',
#      'lij': 'chimica',
#      'lld': 'chimica',
#      'lmo': 'chímica',
#      'ln': 'kémi',
#      'lo': 'ເຄມີສາດ',
#      'lrc': 'کیمیا دونسمنی',
#      'lt': 'chemija',
#      'lv': 'ķīmija',
#      'lzh': '化學',
#      'mai': 'रसायनशास्त्र',
#      'map-bms': 'kimia',
#      'mdf': 'кимиесь',
#      'mg': 'simia',
#      'mhr': 'химий',
#      'mi': 'mātauranga matū',
#      'min': 'kimia',
#      'mk': 'хемија',
#      'ml': 'രസതന്ത്രം',
#      'mn': 'хими',
#      'mni': 'ꯄꯣꯠꯇꯤꯟꯂꯣꯟ',
#      'mr': 'रसायनशास्त्र',
#      'ms': 'kimia',
#      'ms-arab': 'کيميا',
#      'mt': 'kimika',
#      'mwl': 'química',
#      'my': 'ဓာတုဗေဒ',
#      'myv': 'химия',
#      'mzn': 'شیمی',
#      'nan': 'hoà-ha̍k',
#      'nb': 'kjemi',
#      'nds': 'Chemie',
#      'nds-nl': 'Scheikunde',
#      'ne': 'रसायनशास्त्र',
#      'new': 'रसायनशास्त्र',
#      'nl': 'scheikunde',
#      'nn': 'kjemi',
#      'nov': 'kemie',
#      'nrm': 'chimie',
#      'nso': 'khemise',
#      'oc': 'quimia',
#      'om': 'kemistirii',
#      'or': 'ରସାୟନ ବିଜ୍ଞାନ',
#      'os': 'хими',
#      'pa': 'ਰਸਾਇਣ ਵਿਗਿਆਨ',
#      'pcd': 'kémie',
#      'pih': 'kemistrii',
#      'pl': 'chemia',
#      'pnb': 'کیمسٹری',
#      'ps': 'کيميا',
#      'pt': 'química',
#      'pt-br': 'química',
#      'qu': 'chaqllisinchi',
#      'ro': 'chimie',
#      'ru': 'химия',
#      'rue': 'хемія',
#      'rup': 'chimie',
#      'sa': 'रसतन्त्रम्',
#      'sah': 'химия',
#      'sc': 'chìmica',
#      'scn': 'chìmica',
#      'sco': 'chemistrie',
#      'sd': 'ڪيمياءي علم',
#      'se': 'kemiija',
#      'sgs': 'kemėjė',
#      'sh': 'hemija',
#      'shi': 'takrura',
#      'si': 'රසායන විද්\u200dයාව',
#      'sk': 'chémia',
#      'skr': 'کیمسٹری',
#      'sl': 'kemija',
#      'sm': 'kemisi',
#      'smn': 'kemia',
#      'sms': 'kemia',
#      'sn': 'chemishonga',
#      'so': 'kimisteri',
#      'sq': 'kimia',
#      'sr': 'хемија',
#      'ss': 'ikhemisi',
#      'st': 'kemisi',
#      'stq': 'Chemie',
#      'su': 'kimia',
#      'sv': 'kemi',
#      'sw': 'kemia',
#      'szl': 'chymijŏ',
#      'ta': 'வேதியியல்',
#      'tcy': 'ಭೂ ವಿಜ್ಞಾನ',
#      'te': 'రసాయన శాస్త్రము',
#      'tet': 'kímika',
#      'tg': 'кимиё',
#      'th': 'เคมี',
#      'tk': 'himiýa',
#      'tl': 'kimika',
#      'to': 'kemi',
#      'tpi': 'kemistri',
#      'tr': 'kimya',
#      'ts': 'Ntivo-Mirhi',
#      'tt': 'химия',
#      'tum': 'kemistre',
#      'udm': 'химия',
#      'uk': 'хімія',
# ...
#      'it': 'tipo di didattica',
#      'ms': 'pengajaran, pembelajaran dan penyelidikan ilmiah matematik',
#      'my': 'သင်္ချာပညာ သင်ကြားပို့ချခြင်း၊ လေ့လာသင်ယူခြင်းနှင့် ပညာရပ်ဆိုင်ရာ သုတေသန',
#      'pl': 'badania nad nauczaniem i uczeniem się matematyki',
#      'ru': 'преподавание математики в средней школе',
#      'tr': 'öğretim dalı',
#      'zh': '研究數學教學的學科',
#      'zh-hk': '研究數學教學的學科',
#      'zh-tw': '研究數學教學的學科'}},
#    'ancestors': [{'id': 'https://openalex.org/C33923547',
#      'wikidata': 'https://www.wikidata.org/wiki/Q395',
#      'display_name': 'Mathematics',
#      'level': 0},
#     {'id': 'https://openalex.org/C15744967',
#      'wikidata': 'https://www.wikidata.org/wiki/Q9418',
#      'display_name': 'Psychology',
#      'level': 0}],
#    'related_concepts': [{'id': 'https://openalex.org/C33923547',
#      'wikidata': None,
#      'display_name': 'Mathematics',
#      'level': 0,
#      'score': 12.340055},
#     {'id': 'https://openalex.org/C2524010',
#      'wikidata': None,
#      'display_name': 'Geometry',
#      'level': 1,
#      'score': 5.713919},
#     {'id': 'https://openalex.org/C44877443',
#      'wikidata': None,
#      'display_name': 'Science education',
#      'level': 2,
#      'score': 5.347198},
#     {'id': 'https://openalex.org/C72074766',
#      'wikidata': None,
#      'display_name': 'History of mathematics',
#      'level': 2,
#      'score': 3.9987404},
#     {'id': 'https://openalex.org/C182109673',
#      'wikidata': None,
#      'display_name': 'Statistics education',
#      'level': 2,
#      'score': 3.8709488},
#     {'id': 'https://openalex.org/C94375191',
#      'wikidata': None,
#      'display_name': 'Arithmetic',
#      'level': 1,
#      'score': 3.6076188},
#     {'id': 'https://openalex.org/C13553968',
#      'wikidata': None,
#      'display_name': 'Music education',
#      'level': 2,
#      'score': 3.5942678},
#     {'id': 'https://openalex.org/C105795698',
#      'wikidata': None,
#      'display_name': 'Statistics',
#      'level': 1,
#      'score': 3.4154525},
#     {'id': 'https://openalex.org/C121332964',
#      'wikidata': None,
#      'display_name': 'Physics',
#      'level': 0,
#      'score': 3.3057814},
#     {'id': 'https://openalex.org/C36289849',
#      'wikidata': None,
#      'display_name': 'Social science',
#      'level': 1,
#      'score': 3.241048},
#     {'id': 'https://openalex.org/C15744967',
#      'wikidata': None,
#      'display_name': 'Psychology',
#      'level': 0,
#      'score': 3.1475306},
#     {'id': 'https://openalex.org/C40238689',
#      'wikidata': None,
#      'display_name': 'Philosophy of mathematics',
#      'level': 2,
#      'score': 3.0684571},
#     {'id': 'https://openalex.org/C28826006',
#      'wikidata': None,
#      'display_name': 'Applied mathematics',
#      'level': 1,
#      'score': 3.0411484},
#     {'id': 'https://openalex.org/C68333046',
#      'wikidata': None,
#      'display_name': 'English studies',
#      'level': 2,
#      'score': 3.0262785},
#     {'id': 'https://openalex.org/C41008148',
#      'wikidata': None,
#      'display_name': 'Computer science',
#      'level': 0,
#      'score': 3.0157754},
#     {'id': 'https://openalex.org/C36727532',
#      'wikidata': None,
#      'display_name': 'Educational research',
#      'level': 2,
#      'score': 2.201818},
#     {'id': 'https://openalex.org/C50773583',
#      'wikidata': None,
#      'display_name': 'Physics education',
#      'level': 2,
#      'score': 1.7457298},
#     {'id': 'https://openalex.org/C118840557',
#      'wikidata': None,
#      'display_name': 'Connected Mathematics',
#      'level': 2,
#      'score': 1.2952756},
#     {'id': 'https://openalex.org/C173600914',
#      'wikidata': None,
#      'display_name': 'Number sense',
#      'level': 2,
#      'score': 1.1998714},
#     {'id': 'https://openalex.org/C2780120442',
#      'wikidata': None,
#      'display_name': 'Ethnomathematics',
#      'level': 2,
#      'score': 1.1301975},
#     {'id': 'https://openalex.org/C2778778035',
#      'wikidata': None,
#      'display_name': 'Mathematics Subject Classification',
#      'level': 2,
#      'score': 1.064223},
#     {'id': 'https://openalex.org/C511723319',
#      'wikidata': None,
#      'display_name': 'Philosophy education',
#      'level': 2,
#      'score': 1.0107669},
#     {'id': 'https://openalex.org/C547231352',
#      'wikidata': None,
#      'display_name': 'Technology education',
#      'level': 2,
#      'score': 0.98892736},
#     {'id': 'https://openalex.org/C90988201',
#      'wikidata': None,
#      'display_name': 'Word problem (mathematics education)',
#      'level': 2,
#      'score': 0.9725038}],
#    'counts_by_year': [{'year': 2022,
#      'works_count': 59070,
#      'cited_by_count': 369950},
#     {'year': 2021, 'works_count': 160558, 'cited_by_count': 734352},
#     {'year': 2020, 'works_count': 205938, 'cited_by_count': 782842},
#     {'year': 2019, 'works_count': 191596, 'cited_by_count': 831403},
#     {'year': 2018, 'works_count': 178171, 'cited_by_count': 711392},
#     {'year': 2017, 'works_count': 172264, 'cited_by_count': 706436},
#     {'year': 2016, 'works_count': 172527, 'cited_by_count': 797680},
#     {'year': 2015, 'works_count': 173505, 'cited_by_count': 883853},
#     {'year': 2014, 'works_count': 165015, 'cited_by_count': 882010},
#     {'year': 2013, 'works_count': 158770, 'cited_by_count': 806089},
#     {'year': 2012, 'works_count': 148146, 'cited_by_count': 730773}],
#    'works_api_url': 'https://api.openalex.org/works?filter=concepts.id:C145420912',
#    'updated_date': '2022-07-31T11:57:45.467180',
#    'created_date': '2016-06-24'},
#   {'id': 'https://openalex.org/C134018914',
#    'wikidata': 'https://www.wikidata.org/wiki/Q162606',
#    'display_name': 'Endocrinology',
#    'level': 1,
#    'description': 'medical specialty',
#    'works_count': 3095296,
#    'cited_by_count': 73039937,
#    'ids': {'openalex': 'https://openalex.org/C134018914',
#     'wikidata': 'https://www.wikidata.org/wiki/Q162606',
#     'mag': '134018914',
#     'wikipedia': 'https://en.wikipedia.org/wiki/Endocrinology',
#     'umls_cui': ['C0014137']},
#    'image_url': 'https://upload.wikimedia.org/wikipedia/commons/d/d6/Blausen_0345_EndocrineSystem_Female2.png',
#    'image_thumbnail_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Blausen_0345_EndocrineSystem_Female2.png/100px-Blausen_0345_EndocrineSystem_Female2.png',
#    'international': {'display_name': {'ar': 'علم الغدد الصم',
#      'arz': 'علم الغدد الصم',
#      'az': 'Endokrinologiya',
#      'ba': 'Эндокринология',
#      'be': 'эндакрыналогія',
#      'be-tarask': 'эндакрыналёгія',
#      'bg': 'Ендокринология',
#      'bn': 'অন্তঃক্ষরা গ্রন্থিবিজ্ঞান',
#      'bs': 'Endokrinologija',
#      'ca': 'endocrinologia',
#      'cs': 'endokrinologie',
#      'cy': 'endocrinoleg',
#      'da': 'endokrinologi',
#      'de': 'Endokrinologie',
#      'el': 'ενδοκρινολογία',
#      'en': 'endocrinology',
#      'eo': 'endokrinologio',
#      'es': 'endocrinología',
#      'et': 'endokrinoloogia',
#      'eu': 'endokrinologia',
#      'fa': 'غدد درون ریز و متابولیسم',
#      'fi': 'endokrinologia',
#      'fr': 'endocrinologie',
#      'gl': 'Endocrinoloxía',
#      'he': 'אנדוקרינולוגיה',
#      'hi': 'अंतःस्राविकी',
#      'hr': 'Endokrinologija',
#      'hu': 'endokrinológia',
#      'hy': 'էնդոկրինոլոգիա',
#      'id': 'Endokrinologi',
#      'io': 'Endokrinologio',
#      'is': 'Innkirtlafræði',
#      'it': 'endocrinologia',
#      'ja': '内分泌学',
#      'jv': 'Endokrinologi',
#      'ka': 'ენდოკრინოლოგია',
#      'kab': 'Tuskecsent',
#      'kk': 'Эндокринология',
#      'kn': 'ಅಂತಃಸ್ರಾವ ಶಾಸ್ತ್ರ',
#      'ko': '내분비학',
#      'ky': 'Эндокринология',
#      'la': 'Endocrinologia',
#      'lfn': 'endocrinolojia',
#      'lt': 'Endokrinologija',
#      'lv': 'endokrinoloģija',
#      'min': 'Endokrinologi',
#      'mk': 'Ендокринологија',
#      'ml': 'അന്തഃസ്രവവിജ്ഞാനീയം',
#      'ms': 'Endokrinologi',
#      'nan': 'Lāi-hun-pì-ha̍k',
#      'nb': 'endokrinologi',
#      'ne': 'ग्रन्थिशास्त्र',
#      'new': 'इन्डोक्राइनोलोजी',
#      'nl': 'endocrinologie',
#      'nn': 'endokrinologi',
#      'pl': 'endokrynologia',
#      'pt': 'endocrinologia',
#      'ro': 'endocrinologie',
#      'ru': 'эндокринология',
#      'sa': 'ग्रन्थिशास्त्र',
#      'se': 'endokrinologiija',
#      'sh': 'Endokrinologija',
#      'si': 'අන්තරාසර්ග විද්\u200dයාව',
#      'sk': 'Endokrinológia',
#      'sl': 'Endokrinologija',
#      'smn': 'endokrinologia',
#      'sms': 'endokrinologia',
#      'sq': 'Endokrinologjia',
#      'sr': 'ендокринологија',
#      'sr-ec': 'Ендокринологија',
#      'sr-el': 'Endokrinologija',
#      'sv': 'endokrinologi',
#      'ta': 'உட்சுரப்பியல்',
#      'th': 'วิทยาต่อมไร้ท่อ',
#      'tl': 'Endokrinolohiya',
#      'tr': 'Endokrinoloji',
#      'tt': 'Эндокринология',
#      'uk': 'ендокринологія',
#      'ur': 'علم در افرازیات',
#      'uz': 'Endokrinologiya',
#      'vec': 'endocrenołoxia',
#      'vi': 'nội tiết học',
#      'war': 'Endokrinolohiya',
#      'wuu': '内分泌学',
#      'yue': '內分泌學',
#      'zh': '內分泌學',
#      'zh-cn': '内分泌学',
#      'zh-hans': '内分泌学',
#      'zh-hant': '內分泌學',
#      'zh-hk': '內分泌學',
#      'zh-sg': '内分泌学',
#      'zh-tw': '內分泌學'},
#     'description': {'ba': 'эске секреция биҙҙәренең эске төҙөлөшө һәм функциялары тураһында фән',
#      'be-tarask': 'мэдычная спэцыяльнасьць',
#      'bn': 'চিকিৎসাবিজ্ঞানের বিশেষায়িত শাখা',
#      'cy': 'arbenigedd meddygol',
#      'da': 'læren om hormoner og relaterede lidelser',
#      'de': 'Lehre von den Hormonerkrankungen',
#      'el': 'ιατρική ειδικότητα',
#      'en': 'medical specialty',
#      'es': 'especialidad médica',
#      'fa': 'تخصص یا ویژه\u200cگری پزشکی',
#      'fi': 'lääketieteen erikoisala, joka käsittelee hormoneja ja umpieritysrauhasten sairauksia',
#      'fr': 'spécialité médicale',
#      'he': 'תחום ברפואה: חקר ההורמונים',
#      'hu': 'Belső elválasztású mirigyek élettana',
#      'hy': 'բժշկական մասնագիտություն, որը զբաղվում է ներզատիչ գեղձերի հետ կապված հիվանդությունների բուժմամբ',
#      'it': 'specializzazione medica',
#      'lv': 'bioloģijas un medicīnas nozare, kas endokrīno sistēmu, endokrīnās slimības un hormonus',
#      'nn': 'medisinsk spesialområde',
#      'pl': 'specjalność medyczna',
#      'ru': 'раздел медицины',
#      'vec': 'rama de ła medexina interna che ła stùdia el sistema endocreno'}},
#    'ancestors': [{'id': 'https://openalex.org/C86803240',
#      'wikidata': 'https://www.wikidata.org/wiki/Q420',
#      'display_name': 'Biology',
#      'level': 0},
#     {'id': 'https://openalex.org/C71924100',
#      'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#      'display_name': 'Medicine',
#      'level': 0}],
#    'related_concepts': [{'id': 'https://openalex.org/C164705383',
#      'wikidata': None,
#      'display_name': 'Cardiology',
#      'level': 1,
#      'score': 22.496407},
#     {'id': 'https://openalex.org/C16568411',
#      'wikidata': None,
#      'display_name': 'Neurology',
#      'level': 2,
#      'score': 22.088144},
#     {'id': 'https://openalex.org/C90924648',
#      'wikidata': None,
#      'display_name': 'Gastroenterology',
#      'level': 1,
#      'score': 22.074448},
#     {'id': 'https://openalex.org/C71315377',
#      'wikidata': None,
#      'display_name': 'Hormone',
#      'level': 2,
#      'score': 19.573046},
#     {'id': 'https://openalex.org/C555293320',
#      'wikidata': None,
#      'display_name': 'Diabetes mellitus',
#      'level': 2,
#      'score': 19.09213},
#     {'id': 'https://openalex.org/C126322002',
#      'wikidata': None,
#      'display_name': 'Internal medicine',
#      'level': 1,
#      'score': 16.886675},
#     {'id': 'https://openalex.org/C187212893',
#      'wikidata': None,
#      'display_name': 'Pediatrics',
#      'level': 1,
#      'score': 16.61497},
#     {'id': 'https://openalex.org/C29456083',
#      'wikidata': None,
#      'display_name': 'Gynecology',
#      'level': 1,
#      'score': 16.270739},
#     {'id': 'https://openalex.org/C126894567',
#      'wikidata': None,
#      'display_name': 'Urology',
#      'level': 1,
#      'score': 16.092428},
#     {'id': 'https://openalex.org/C54847362',
#      'wikidata': None,
#      'display_name': 'Nephrology',
#      'level': 2,
#      'score': 14.458572},
#     {'id': 'https://openalex.org/C118487528',
#      'wikidata': None,
#      'display_name': 'Ophthalmology',
#      'level': 1,
#      'score': 14.3009405},
#     {'id': 'https://openalex.org/C68312169',
#      'wikidata': None,
#      'display_name': 'Orthopedic surgery',
#      'level': 2,
#      'score': 14.229307},
#     {'id': 'https://openalex.org/C143998085',
#      'wikidata': None,
#      'display_name': 'Oncology',
#      'level': 1,
#      'score': 14.228102},
#     {'id': 'https://openalex.org/C142724271',
#      'wikidata': None,
#      'display_name': 'Pathology',
#      'level': 1,
#      'score': 12.934857},
#     {'id': 'https://openalex.org/C118552586',
#      'wikidata': None,
#      'display_name': 'Psychiatry',
#      'level': 1,
#      'score': 12.728467},
#     {'id': 'https://openalex.org/C526584372',
#      'wikidata': None,
#      'display_name': 'Thyroid',
#      'level': 2,
#      'score': 12.028729},
#     {'id': 'https://openalex.org/C42407357',
#      'wikidata': None,
#      'display_name': 'Physiology',
#      'level': 1,
#      'score': 11.922272},
#     {'id': 'https://openalex.org/C198451711',
#      'wikidata': None,
#      'display_name': 'Rheumatology',
#      'level': 2,
#      'score': 11.80772},
#     {'id': 'https://openalex.org/C194409129',
#      'wikidata': None,
#      'display_name': 'Hematology',
#      'level': 2,
#      'score': 11.0566435},
#     {'id': 'https://openalex.org/C179585855',
#      'wikidata': None,
#      'display_name': 'Pulmonology',
#      'level': 2,
#      'score': 9.458584},
#     {'id': 'https://openalex.org/C2778491484',
#      'wikidata': None,
#      'display_name': 'Hypopituitarism',
#      'level': 2,
#      'score': 9.1339},
#     {'id': 'https://openalex.org/C54183767',
#      'wikidata': None,
#      'display_name': 'Geriatrics',
#      'level': 2,
#      'score': 7.3210955},
#     {'id': 'https://openalex.org/C2776211905',
#      'wikidata': None,
#      'display_name': 'Pediatric endocrinology',
#      'level': 2,
#      'score': 5.400356},
#     {'id': 'https://openalex.org/C41260117',
#      'wikidata': None,
#      'display_name': 'Hepatology',
#      'level': 2,
#      'score': 3.4722996},
#     {'id': 'https://openalex.org/C16685009',
#      'wikidata': None,
#      'display_name': 'Andrology',
#      'level': 1,
#      'score': 2.0551193},
#     {'id': 'https://openalex.org/C2777669169',
#      'wikidata': None,
#      'display_name': 'Incidentaloma',
#      'level': 2,
#      'score': 1.8526561},
#     {'id': 'https://openalex.org/C2781449511',
#      'wikidata': None,
#      'display_name': 'Pituitary tumors',
#      'level': 2,
#      'score': 1.8324549},
#     {'id': 'https://openalex.org/C2780358146',
#      'wikidata': None,
#      'display_name': 'Hospital medicine',
#      'level': 2,
#      'score': 1.6312581},
#     {'id': 'https://openalex.org/C2778991426',
#      'wikidata': None,
#      'display_name': 'Neurosecretion',
#      'level': 2,
#      'score': 0.98953044},
#     {'id': 'https://openalex.org/C2776429440',
#      'wikidata': None,
#      'display_name': 'Intractable pain',
#      'level': 2,
#      'score': 0.87774545},
#     {'id': 'https://openalex.org/C2777012970',
#      'wikidata': None,
#      'display_name': 'Respiratory Medicine',
#      'level': 2,
#      'score': 0.85420334}],
#    'counts_by_year': [{'year': 2022,
#      'works_count': 46335,
#      'cited_by_count': 1715115},
#     {'year': 2021, 'works_count': 86674, 'cited_by_count': 3335870},
#     {'year': 2020, 'works_count': 80798, 'cited_by_count': 3162978},
#     {'year': 2019, 'works_count': 78580, 'cited_by_count': 2891427},
#     {'year': 2018, 'works_count': 74987, 'cited_by_count': 2652010},
#     {'year': 2017, 'works_count': 77046, 'cited_by_count': 2936218},
#     {'year': 2016, 'works_count': 80039, 'cited_by_count': 2900533},
#     {'year': 2015, 'works_count': 86620, 'cited_by_count': 3076995},
#     {'year': 2014, 'works_count': 88901, 'cited_by_count': 3073945},
#     {'year': 2013, 'works_count': 90029, 'cited_by_count': 3057310},
#     {'year': 2012, 'works_count': 88257, 'cited_by_count': 2953656}],
#    'works_api_url': 'https://api.openalex.org/works?filter=concepts.id:C134018914',
#    'updated_date': '2022-07-31T11:49:42.895119',
#    'created_date': '2016-06-24'}],
#  'group_by': []}

# %% [markdown]
# To get a meaningful list of entity objects, we need to add parameters to ```filter```, ```search``` and ```sort``` the returned result.

# %% [markdown]
# Filter parameters could be formatted like: ```filter=attribute:value,attribute2:value2```
# For instance, we want to get all the level-0 concepts:

# %%
level_zero_concepts = requests.get(
    'https://api.openalex.org/concepts?filter=level:0'
).json()

# %%
for c in level_zero_concepts['results']:
    print(c['display_name'])
# Out:
# Computer science
# Medicine
# Chemistry
# Psychology
# Biology
# Political science
# Materials science
# Art
# Business
# Geography
# Physics
# Environmental science
# Mathematics
# Philosophy
# Sociology
# History
# Geology
# Engineering
# Economics

# %% [markdown]
# Getting venues that published more than 1000 research works：

# %%
big_venues = requests.get(
    'https://api.openalex.org/venues?filter=works_count:>1000'
).json()

# %%
for v in big_venues['results']:
    print(v['display_name'])
# Out:
# Social Science Research Network
# Research Papers in Economics
# ChemInform
# Lecture Notes in Computer Science
# The Lancet
# BMJ
# Nature
# Science
# Notes and Queries
# PLOS ONE
# JAMA
# Bulletin of the American Physical Society
# Social Science Research Network
# Reactions Weekly
# Journal of the American Chemical Society
# Journal of Biological Chemistry
# Physical Review B
# Scientific American
# Choice Reviews Online
# Chemical & Engineering News
# Journal of physics
# Blood
# Scientific Reports
# Journal of the Acoustical Society of America
# Proceedings of the National Academy of Sciences of the United States of America

# %% [markdown]
# Institutions that are outside of the US:

# %%
non_us_institutions = requests.get(
    'https://api.openalex.org/institutions?filter=country_code:!us'
).json()

# %%
for i in non_us_institutions['results']:
    print(i['display_name'])
# Out:
# University of Tokyo
# University of Toronto
# University of Oxford
# University of Cambridge
# Tsinghua University
# University of British Columbia
# Kyoto University
# University College London
# Imperial College London
# Tohoku University
# Universidade de São Paulo
# Zhejiang University
# Osaka University
# University of Liège
# Shanghai Jiao Tong University
# McGill University
# Sapienza University of Rome
# University of Alberta
# National University of Singapore
# University of Melbourne
# Kyushu University
# University of Manchester
# University of Queensland
# University of Sydney
# National Autonomous University of Mexico

# %% [markdown]
# We can also search by fields:

# %%
authors_named_leibniz = requests.get('https://api.openalex.org/authors?filter=display_name.search:leibniz').json()

# %%
for a in authors_named_leibniz['results']:
    print(a['display_name'])
# Out:
# Gottfried Wilhelm Leibniz
# Leibniz, Gottfried Wilhelm, Freiherr von
# Leibniz Hang
# Leibniz-Informationszentrum Wirtschaft
# Leibniz, Gottfried Wilhelm, Freiherr von
# Freiherr von Leibniz
# Gottfried Wilhelm Leibniz
# Leibniz
# Gottfried Wilhelm Leibniz
# Wilhelm Leibniz
# Gottfried Wilhelm Leibniz
# Leibniz-Informationszentrum Wirtschaft
# Leibniz Universit
# Leibniz-Informationszentrum Wirtschaft
# Gottfried Wilhelm Leibniz
# Otto Leibniz
# Gottfried Wilhelm Leibniz
# Gesis Leibniz-Institut für Sozialwissenschaften
# Leibniz, Gottfried Wilhelm, Freiherr von
# Gottfried Wilhelm Leibniz
# Leibniz, Gottfried Wilhelm, Freiherr von
# Leibniz, Gottfried Wilhelm, Freiherr von
# Leibniz
# Leibniz-Institut für Länderkunde Leipzig
# Gottfried Wilhelm Leibniz

# %%
most_popular_after_2010 = requests.get(
    'https://api.openalex.org/works?sort=cited_by_count:desc&filter=publication_year:>2010'
).json()

# %%
for w in most_popular_after_2010['results']:
    print('Work Name: ' + w['display_name'])
    print('Cited Times: ' + str(w['cited_by_count']) + '\n')
# Out:
# Work Name: R: A language and environment for statistical computing.
# Cited Times: 129391
#
# Work Name: Diagnostic and Statistical Manual of Mental Disorders
# Cited Times: 110641
#
# Work Name: Deep Residual Learning for Image Recognition
# Cited Times: 82349
#
# Work Name: Adam: A Method for Stochastic Optimization
# Cited Times: 48873
#
# Work Name: ImageNet Classification with Deep Convolutional Neural Networks
# Cited Times: 47116
#
# Work Name: CRC Handbook of Chemistry and Physics
# Cited Times: 45113
#
# Work Name: Hallmarks of cancer: the next generation.
# Cited Times: 40467
#
# Work Name: Global cancer statistics 2018: GLOBOCAN estimates of incidence and mortality worldwide for 36 cancers in 185 countries
# Cited Times: 39534
#
# Work Name: Very Deep Convolutional Networks for Large-Scale Image Recognition
# Cited Times: 37620
#
# Work Name: Deep learning
# Cited Times: 36889
#
# Work Name: LIBSVM: A library for support vector machines
# Cited Times: 36682
#
# Work Name: Fitting Linear Mixed-Effects Models Using lme4
# Cited Times: 36417
#
# Work Name: MEGA5: Molecular Evolutionary Genetics Analysis using Maximum Likelihood, Evolutionary Distance, and Maximum Parsimony Methods
# Cited Times: 35398
#
# Work Name: NIH Image to ImageJ: 25 years of image analysis
# Cited Times: 33736
#
# Work Name: MEGA6: Molecular Evolutionary Genetics Analysis Version 6.0
# Cited Times: 32604
#
# Work Name: Moderated estimation of fold change and dispersion for RNA-seq data with DESeq2
# Cited Times: 31927
#
# Work Name: Fiji: an open-source platform for biological-image analysis
# Cited Times: 31654
#
# Work Name: Scikit-learn: Machine Learning in Python
# Cited Times: 30878
#
# Work Name: U-Net: Convolutional Networks for Biomedical Image Segmentation
# Cited Times: 28479
#
# Work Name: Stress: Appraisal and Coping
# Cited Times: 27833
#
# Work Name: Trimmomatic: a flexible trimmer for Illumina sequence data
# Cited Times: 27821
#
# Work Name: Fast gapped-read alignment with Bowtie 2
# Cited Times: 26878
#
# Work Name: Clinical features of patients infected with 2019 novel coronavirus in Wuhan, China
# Cited Times: 26862
#
# Work Name: MEGA7: Molecular Evolutionary Genetics Analysis version 7.0 for bigger datasets
# Cited Times: 24841
#
# Work Name: BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding
# Cited Times: 24567

# %% [markdown]
# In some occasions, we want to group the returned results into facets. ```group_by``` parameter is available for such task.
# To give an example, we want to know the distribution of open access status in OpenAlex:

# %%
works_oa = requests.get('https://api.openalex.org/works?group_by=oa_status').json()

# %%
works_oa
# Out:
# {'meta': {'count': 6, 'db_response_time_ms': 981, 'page': 1, 'per_page': 200},
#  'results': [],
#  'group_by': [{'key': 'unknown',
#    'key_display_name': 'unknown',
#    'count': 108836134},
#   {'key': 'closed', 'key_display_name': 'closed', 'count': 91761584},
#   {'key': 'bronze', 'key_display_name': 'bronze', 'count': 13496370},
#   {'key': 'gold', 'key_display_name': 'gold', 'count': 12663915},
#   {'key': 'green', 'key_display_name': 'green', 'count': 7937031},
#   {'key': 'hybrid', 'key_display_name': 'hybrid', 'count': 4212965}]}

# %% [markdown]
# We can also combine groups with filter. For example, we want to know the distribution of open access status for journal articles in OpenAlex:

# %%
journal_works_oa = requests.get('https://api.openalex.org/works?filter=type:journal-article&group_by=oa_status').json()

# %%
journal_works_oa
# Out:
# {'meta': {'count': 6, 'db_response_time_ms': 846, 'page': 1, 'per_page': 200},
#  'results': [],
#  'group_by': [{'key': 'closed',
#    'key_display_name': 'closed',
#    'count': 61898016},
#   {'key': 'unknown', 'key_display_name': 'unknown', 'count': 24022732},
#   {'key': 'gold', 'key_display_name': 'gold', 'count': 12146871},
#   {'key': 'bronze', 'key_display_name': 'bronze', 'count': 11830219},
#   {'key': 'green', 'key_display_name': 'green', 'count': 5664621},
#   {'key': 'hybrid', 'key_display_name': 'hybrid', 'count': 3203087}]}
